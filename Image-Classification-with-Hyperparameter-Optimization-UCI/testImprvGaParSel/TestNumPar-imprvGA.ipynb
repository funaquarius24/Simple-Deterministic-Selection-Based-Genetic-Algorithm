# %%
import numpy as np # linear algebra
import pandas as pd # data processing, 
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# importing Random Forest classifier
from sklearn.ensemble import RandomForestClassifier


import os
from pathlib import Path
import time
from collections import OrderedDict, namedtuple

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

# %%
if IN_COLAB:

    from google.colab import drive
    drive._mount('/drive', force_remount=True)
    datadir = '/drive/My Drive/Colab Notebooks/Datasets/'
    optim_dir = datadir + '/optim_dir/'
    results_folder = datadir+'/results/UCI/'
    Path(results_folder).mkdir(parents=True, exist_ok=True)
    Path(optim_dir).mkdir(parents=True, exist_ok=True)
else:
  results_folder = 'results'
  optim_dir = 'optim_dir'
  Path("results").mkdir(parents=True, exist_ok=True)
  Path(optim_dir).mkdir(parents=True, exist_ok=True)


# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO
# Out:
# Mounted at /drive

# %%
import sys

# !pip install category_encoders
import category_encoders as ce

if IN_COLAB:
  
  scripts_dir = '/drive/My Drive/Colab Notebooks/scripts/'
  sys.path.insert(1, scripts_dir)
# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO

# insert at 1, 0 is the script path (or '' in REPL)
else:
    sys.path.insert(1, 'scripts')
from geneticalgorithmOptd import geneticalgorithmOptd as gaOptd
import pickle
# Out:
# ...
#      |████████████████████████████████| 82 kB 446 kB/s
# ...

# %%
for i in range (1, 10):
    Npar = i/10
#     param2 = j 
    print(i/10)
    
    # %run ../drive/MyDrive/Colab\ Notebooks/AI-image-classif-hypp-opt/Image-Classification-with-Hyperparameter-Optimization-UCI/testImprvGaParSel/TestRandFBreastCancer-imprvGA.ipynb
    # %run ../drive/MyDrive/Colab\ Notebooks/AI-image-classif-hypp-opt/Image-Classification-with-Hyperparameter-Optimization-UCI/testImprvGaParSel/TestRandFCar-imprvGA.ipynb
    # %run ../drive/MyDrive/Colab\ Notebooks/AI-image-classif-hypp-opt/Image-Classification-with-Hyperparameter-Optimization-UCI/testImprvGaParSel/TestRandFLetter-imprvGA.ipynb
    # %run ../drive/MyDrive/Colab\ Notebooks/AI-image-classif-hypp-opt/Image-Classification-with-Hyperparameter-Optimization-UCI/testImprvGaParSel/TestRandFAdult-imprvGA.ipynb
# Out:
# Streaming output truncated to the last 5000 lines.
# test acc:  0.8582249974408844
# run_params: {'n': 35, 'm': 14} Train Acc: 0.9989031239031239 Test Acc: 0.8533114955471389
# test acc:  0.8533114955471389
# run_params: {'n': 160, 'm': 10} Train Acc: 1.0 Test Acc: 0.8545398710205753
# test acc:  0.8545398710205753
# run_params: {'n': 160, 'm': 8} Train Acc: 1.0 Test Acc: 0.8539256832838571
# test acc:  0.8539256832838571
# run_params: {'n': 160, 'm': 14} Train Acc: 1.0 Test Acc: 0.8582249974408844
# test acc:  0.8582249974408844
# iterations 10
# run_params: {'n': 106, 'm': 14} Train Acc: 1.0 Test Acc: 0.8561777049851571
# test acc:  0.8561777049851571
# run_params: {'n': 54, 'm': 15} Train Acc: 0.9995612495612496 Test Acc: 0.8547446002661481
# test acc:  0.8547446002661481
# run_params: {'n': 160, 'm': 14} Train Acc: 1.0 Test Acc: 0.8582249974408844
# test acc:  0.8582249974408844
# run_params: {'n': 160, 'm': 14} Train Acc: 1.0 Test Acc: 0.8582249974408844
# ...

# %%
import os 
cwd = os.getcwd()

# %%
# !ls ../drive/MyDrive
# Out:
# '03.Electrical Distribution System Modeling and Analysis in MATLAB and Simulink_clip (1).mp4'
# '03.Electrical Distribution System Modeling and Analysis in MATLAB and Simulink_clip.mp4'
# '06.Matlab Simulation of ACTIVE AND REACTIVE POWER.mp4'
# '128 Novel Piers Anthony Collection (epub and mobi)'
# '500L CLASS'
#  abu
# '[AnimeKaizoku] Mushoku Tensei Jobless Reincarnation 844p BD Dual Audio [DemonAlpha].zip'
# 'applsci-1474360 - Copy (2).docx'
#  Arduino
# 'Arduino (1)'
# 'blockchain correction.docx'
# 'Bro Aziz pro'
# 'Colab Notebooks'
#  DriveWorkspace
#  dump
# 'eeen413 assignments'
#  Files
#  Ibrahim_pro.zip
#  Islam
#  Ismail
# 'iwo-hjjw-oaw - Aug 24, 2021.gjam'
# 'king fahad uni ics'
#  Mine
#  text.txt
#  tickets
#  Untitled0.ipynb
#  Video_1613404466.wmv
#  Video_1613411231.wmv
#  Video_1615799331.wmv
#  Video_1615800523.wmv
#  Work
#  workspace
# 'workspace (1)'
#  XLoader
# 'yusuf zakari'
