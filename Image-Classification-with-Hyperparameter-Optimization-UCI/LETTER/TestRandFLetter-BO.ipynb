# %%
import numpy as np # linear algebra
import pandas as pd # data processing, 
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# importing Random Forest classifier
from sklearn.ensemble import RandomForestClassifier


import os
from pathlib import Path
import time
from collections import OrderedDict, namedtuple

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian-optimization-1.2.0.tar.gz (14 kB)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.19.5)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.1.0)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-py3-none-any.whl size=11685 sha256=57ce0227e6d8d28b2cd931de5e277a92ead6be37162376d02102f6aceadfe641
#   Stored in directory: /root/.cache/pip/wheels/fd/9b/71/f127d694e02eb40bcf18c7ae9613b88a6be4470f57a8528c5b
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.2.0

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

# %%
if IN_COLAB:

    from google.colab import drive
    drive._mount('/drive', force_remount=True)
    datadir = '/drive/My Drive/Colab Notebooks/Datasets/'
    optim_dir = datadir + '/optim_dir/'
    results_folder = datadir+'/results/UCI/'
    Path(results_folder).mkdir(parents=True, exist_ok=True)
    Path(optim_dir).mkdir(parents=True, exist_ok=True)
else:
  results_folder = 'results'
  optim_dir = 'optim_dir'
  Path("results").mkdir(parents=True, exist_ok=True)
  Path(optim_dir).mkdir(parents=True, exist_ok=True)


# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO
# Out:
# Mounted at /drive

# %%
import sys

# !pip install category_encoders
import category_encoders as ce

if IN_COLAB:
  
  scripts_dir = '/drive/My Drive/Colab Notebooks/scripts/'
  sys.path.insert(1, scripts_dir)
# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO

# insert at 1, 0 is the script path (or '' in REPL)
else:
    sys.path.insert(1, 'scripts')
from bayes_opt import BayesianOptimization
import pickle
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.3.0-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 320 kB/s
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.19.5)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.0.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.3.0

# %%
# Enable GPU processing
# if IN_COLAB:
#     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# else:
#     device = torch.device("cpu")
# print(f'Device type: {device}')

# %%
# Set random seed
seed = 777
# torch.manual_seed(seed)
model = None

# %%
import random
def seeding(SEED):
    np.random.seed(SEED)
    random.seed(SEED)
    os.environ['PYTHONHASHSEED'] = str(SEED)
    os.environ['TF_CUDNN_DETERMINISTIC'] = str(SEED)
    # tf.random.set_seed(SEED)
    print('seeding done!!!')
seeding(seed)
# Out:
# seeding done!!!

# %%
df = pd.read_csv(f"{datadir}UCI/Letter/data.csv")

# %%
df.head()
# Out:
#   letter  xbox   ybox   width   height  ...  xy2bar  xedge   xedgey  yedge   yedgex
# 0      T      2      8       3       5  ...       8       0       8       0       8
# 1      I      5     12       3       7  ...       9       2       8       4      10
# 2      D      4     11       6       8  ...       7       3       7       3       9
# 3      N      7     11       6       6  ...      10       6      10       2       8
# 4      G      2      1       3       1  ...       9       1       7       5      10
#
# [5 rows x 17 columns]

# %%
df.shape
# Out:
# (20000, 17)

# %%
x = df.drop(['letter'], axis=1)
y = df['letter']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 42) # Split dataset into train and test sets

# %%
X_train.shape, X_test.shape # Get the dimensions of features
# Out:
# ((16000, 16), (4000, 16))

# %%
X_train.head()
# Out:
#       xbox   ybox   width   height  ...  xedge   xedgey  yedge   yedgex
# 5894      4      7       5       5  ...       3       8       4       8
# 3728      4      7       6       5  ...       3       8       4       7
# 8958      3      5       4       3  ...       5       9       2       6
# 7671      4     10       6       7  ...       3       8       6       9
# 5999      4     10       6       8  ...       3      11       1       8
#
# [5 rows x 16 columns]

# %%
# Create a class to manage the training / hyperparameter runs
class RunManager():
  def __init__(self):
    self.run_params = None
    self.run_count = 0
    self.run_data = []
    
    #---
    self.results = None

  def begin_run(self, run):
    self.run_params = run
    self.run_count += 1
    

  def end_run(self, train_accuracy, test_accuracy):
    # self.epoch_count = 0
    # train_accuracy = 
    # test_accuracy = 

    print(f'run_params: {self.run_params} Train Acc: {train_accuracy} Test Acc: {test_accuracy}')

    results = OrderedDict()
    results['run'] = self.run_count
    results['train acc'] = train_accuracy
    results['test acc'] = test_accuracy
    
    # ---
    self.results = results

    for k, v in self.run_params.items():
      results[k] = v

    self.run_data.append(results)

  def save_output(self, filename):
    if filename:
      filename = filename
      pd.DataFrame.from_dict(self.run_data, orient='columns').to_csv(f'{filename}.csv')
      
      # with open(f'{filename}.json', 'w', encoding='utf-8') as f:
      #   json.dump(self.run_data, f, ensure_ascii=False, indent=4)

      # print('Results saved to disk')

    return pd.DataFrame.from_dict(self.run_data, orient='columns')

# %%
# Define training loop execution
def execution_loop(m, args): # args is given by the optimizer
    agent = {}
    agents = []
    
    agent['n'] = args[0].astype(int)
    agent['m'] = int(args[1])
    agents.append(agent)
#     m = RunManager()
    for run in agents: # this should be one. a particle in pso

        # print(f'Run Params: {run}')

        m.begin_run(run)

        num_predictors = X_train.shape[1]
        if run['m'] <= num_predictors:

          rfc = RandomForestClassifier(n_estimators=run['n'], max_features=run['m'], random_state=0)
          rfc.fit(X_train, y_train)

          y_pred_train = rfc.predict(X_train)
          y_pred_test = rfc.predict(X_test)

          train_score = accuracy_score(y_train, y_pred_train)
          test_score = accuracy_score(y_test, y_pred_test)
        else:
          train_score = 0
          test_score = 0

        m.end_run(train_score, test_score)
    return m.results['test acc']

# %%
# Define training run hyperparameters
params = {
    'n' : [1, 200],
    'm' : [1, 20]
}

# params = OrderedDict(
#     lr = [0, 1],
#     batch_size = [20 2000],
#     n_epochs = [3]
# )

# %%
m = RunManager()
timestr = time.strftime("%Y%m%d-%H%M%S")
filename = f'Run_Results-UCI-Letter-BO-{timestr}'
# filename = 'Run_Results-PSO-20210504-035642-cont.csv' # this is for trying to continue from last optim save

# %%
def run_train_model(agent):
    test_acc = execution_loop(m, agent)
    m.save_output(f'{results_folder}/{filename}')
    print("test acc: ", test_acc)
    return test_acc * -1

# %%
def run_train_model_proxy(n_estimators, max_features):
    agent = [n_estimators, max_features]
    print(agent)
    return run_train_model(agent) * -1

# %%
verbose = True
pop_size = 15   
max_iter = 10

obj_func = run_train_model_proxy

lb = [params['n'][0], params['m'][0]]
ub = [params['n'][1], params['m'][1]]

tic = time.perf_counter()
# Run Bayesian Optimization

params_gbm ={
    'max_features':(1, 20), 'n_estimators':(1, 200)
}

gbm_bo = BayesianOptimization(f = obj_func, pbounds = params_gbm, random_state=777)
gbm_bo.maximize(init_points=15, n_iter=135)

toc = time.perf_counter()
print(f'Time to execute: {toc - tic:0.4f} seconds')
# print(f'Best Position: {[int(x) for x in best_pos1]} Best Solution: {best_fit1:0.5f}')
print(gbm_bo.max)


# m.save_output(f'{results_folder}/{filename}')
# print('Results saved.')
# Out:
# |   iter    |  target   | max_fe... | n_esti... |
# -------------------------------------------------
# [61.16896533179672, 3.9006109631251182]
# run_params: {'n': 61, 'm': 3} Train Acc: 1.0 Test Acc: 0.95975
# test acc:  0.95975
# |  1        |  0.9597   |  3.901    |  61.17    |
# [92.5122079801848, 2.178691879576678]
# run_params: {'n': 92, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# |  2        |  0.96     |  2.179    |  92.51    |
# [185.47241250222905, 16.869814304314936]
# run_params: {'n': 185, 'm': 16} Train Acc: 1.0 Test Acc: 0.938
# test acc:  0.938
# |  3        |  0.938    |  16.87    |  185.5    |
# [153.93074816220832, 14.812790702062332]
# run_params: {'n': 153, 'm': 14} Train Acc: 1.0 Test Acc: 0.94525
# test acc:  0.94525
# |  4        |  0.9453   |  14.81    |  153.9    |
# [129.16182912212687, 6.114896262971671]
# run_params: {'n': 129, 'm': 6} Train Acc: 1.0 Test Acc: 0.96175
# test acc:  0.96175
# |  5        |  0.9617   |  6.115    |  129.2    |
# [16.857491236685103, 2.774091879755339]
# run_params: {'n': 16, 'm': 2} Train Acc: 1.0 Test Acc: 0.93925
# test acc:  0.93925
# |  6        |  0.9393   |  2.774    |  16.86    |
# [69.32476710616542, 12.202661315661421]
# run_params: {'n': 69, 'm': 12} Train Acc: 1.0 Test Acc: 0.94925
# test acc:  0.94925
# |  7        |  0.9493   |  12.2     |  69.32    |
# [125.66816803972203, 19.788646822882352]
# run_params: {'n': 125, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  8        |  0.0      |  19.79    |  125.7    |
# [110.89910593369481, 13.953806315838111]
# run_params: {'n': 110, 'm': 13} Train Acc: 1.0 Test Acc: 0.9505
# test acc:  0.9505
# |  9        |  0.9505   |  13.95    |  110.9    |
# [75.27861790093249, 6.108341099876924]
# run_params: {'n': 75, 'm': 6} Train Acc: 1.0 Test Acc: 0.962
# test acc:  0.962
# |  10       |  0.962    |  6.108    |  75.28    |
# [38.102077470988675, 5.235633880928866]
# run_params: {'n': 38, 'm': 5} Train Acc: 1.0 Test Acc: 0.95775
# test acc:  0.95775
# |  11       |  0.9577   |  5.236    |  38.1     |
# [39.439318721728014, 8.422313775619182]
# run_params: {'n': 39, 'm': 8} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# |  12       |  0.9543   |  8.422    |  39.44    |
# [176.67888100610892, 12.60730769574733]
# run_params: {'n': 176, 'm': 12} Train Acc: 1.0 Test Acc: 0.9525
# test acc:  0.9525
# |  13       |  0.9525   |  12.61    |  176.7    |
# [51.37066989670935, 12.824437662091054]
# run_params: {'n': 51, 'm': 12} Train Acc: 1.0 Test Acc: 0.94975
# test acc:  0.94975
# |  14       |  0.9497   |  12.82    |  51.37    |
# [163.46448945399737, 4.418675827834511]
# run_params: {'n': 163, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# |  15       |  0.9635   |  4.419    |  163.5    |
# [140.9061677510061, 1.118480808398219]
# run_params: {'n': 140, 'm': 1} Train Acc: 1.0 Test Acc: 0.955
# test acc:  0.955
# |  16       |  0.955    |  1.118    |  140.9    |
# [107.79425973183457, 1.0]
# run_params: {'n': 107, 'm': 1} Train Acc: 1.0 Test Acc: 0.953
# test acc:  0.953
# |  17       |  0.953    |  1.0      |  107.8    |
# [97.89491474002166, 15.787370258331858]
# run_params: {'n': 97, 'm': 15} Train Acc: 1.0 Test Acc: 0.94225
# test acc:  0.94225
# |  18       |  0.9423   |  15.79    |  97.89    |
# [25.1747201893024, 18.07780094343894]
# run_params: {'n': 25, 'm': 18} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  19       |  0.0      |  18.08    |  25.17    |
# [1.3061654431745886, 1.0779515864806348]
# run_params: {'n': 1, 'm': 1} Train Acc: 0.8903125 Test Acc: 0.71175
# test acc:  0.71175
# |  20       |  0.7117   |  1.078    |  1.306    |
# [82.76323701350839, 19.22677069084489]
# run_params: {'n': 82, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  21       |  0.0      |  19.23    |  82.76    |
# [47.88329188975235, 1.1528891632057945]
# run_params: {'n': 47, 'm': 1} Train Acc: 1.0 Test Acc: 0.94975
# test acc:  0.94975
# |  22       |  0.9497   |  1.153    |  47.88    |
# [166.00127537857193, 20.0]
# run_params: {'n': 166, 'm': 20} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  23       |  0.0      |  20.0     |  166.0    |
# [101.82485365978029, 7.7447535185022005]
# run_params: {'n': 101, 'm': 7} Train Acc: 1.0 Test Acc: 0.9585
# test acc:  0.9585
# |  24       |  0.9585   |  7.745    |  101.8    |
# [151.7663042165186, 4.513073755116056]
# run_params: {'n': 151, 'm': 4} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# |  25       |  0.9625   |  4.513    |  151.8    |
# [182.66336984676954, 3.9922576000601224]
# run_params: {'n': 182, 'm': 3} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# |  26       |  0.9635   |  3.992    |  182.7    |
# [120.87375990463552, 1.0371448179495508]
# run_params: {'n': 120, 'm': 1} Train Acc: 1.0 Test Acc: 0.9535
# test acc:  0.9535
# |  27       |  0.9535   |  1.037    |  120.9    |
# [196.524828483757, 7.355623663841008]
# run_params: {'n': 196, 'm': 7} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# |  28       |  0.96     |  7.356    |  196.5    |
# [199.9149816586708, 19.17510983441899]
# run_params: {'n': 199, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  29       |  0.0      |  19.18    |  199.9    |
# [143.9732459491811, 12.137913720662434]
# run_params: {'n': 143, 'm': 12} Train Acc: 1.0 Test Acc: 0.951
# test acc:  0.951
# |  30       |  0.951    |  12.14    |  144.0    |
# [172.83963127604605, 1.0]
# run_params: {'n': 172, 'm': 1} Train Acc: 1.0 Test Acc: 0.95375
# test acc:  0.95375
# |  31       |  0.9537   |  1.0      |  172.8    |
# [60.067424447139935, 20.0]
# run_params: {'n': 60, 'm': 20} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  32       |  0.0      |  20.0     |  60.07    |
# [192.35138002341083, 1.2281763856804546]
# run_params: {'n': 192, 'm': 1} Train Acc: 1.0 Test Acc: 0.95575
# test acc:  0.95575
# |  33       |  0.9557   |  1.228    |  192.4    |
# [68.61287266652059, 1.043681207244541]
# run_params: {'n': 68, 'm': 1} Train Acc: 1.0 Test Acc: 0.95175
# test acc:  0.95175
# |  34       |  0.9517   |  1.044    |  68.61    |
# [1.0, 20.0]
# run_params: {'n': 1, 'm': 20} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  35       |  0.0      |  20.0     |  1.0      |
# [27.599760907491728, 1.0005217332845775]
# run_params: {'n': 27, 'm': 1} Train Acc: 1.0 Test Acc: 0.94125
# test acc:  0.94125
# |  36       |  0.9413   |  1.001    |  27.6     |
# [105.10141098992406, 20.0]
# run_params: {'n': 105, 'm': 20} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  37       |  0.0      |  20.0     |  105.1    |
# [113.82211183930175, 7.10292206505644]
# run_params: {'n': 113, 'm': 7} Train Acc: 1.0 Test Acc: 0.959
# test acc:  0.959
# |  38       |  0.959    |  7.103    |  113.8    |
# [188.5948597702459, 9.11150174522674]
# run_params: {'n': 188, 'm': 9} Train Acc: 1.0 Test Acc: 0.9555
# test acc:  0.9555
# |  39       |  0.9555   |  9.112    |  188.6    |
# [93.70223421870772, 10.108552909780746]
# run_params: {'n': 93, 'm': 10} Train Acc: 1.0 Test Acc: 0.9555
# test acc:  0.9555
# |  40       |  0.9555   |  10.11    |  93.7     |
# [83.02982638820357, 1.0]
# run_params: {'n': 83, 'm': 1} Train Acc: 1.0 Test Acc: 0.95225
# test acc:  0.95225
# |  41       |  0.9523   |  1.0      |  83.03    |
# [146.76072902351336, 20.0]
# run_params: {'n': 146, 'm': 20} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  42       |  0.0      |  20.0     |  146.8    |
# [137.52049420773463, 8.05292257996569]
# run_params: {'n': 137, 'm': 8} Train Acc: 1.0 Test Acc: 0.95775
# test acc:  0.95775
# |  43       |  0.9577   |  8.053    |  137.5    |
# [43.674356333296316, 17.86311405833062]
# run_params: {'n': 43, 'm': 17} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  44       |  0.0      |  17.86    |  43.67    |
# [53.42234498840892, 6.315779207020894]
# run_params: {'n': 53, 'm': 6} Train Acc: 1.0 Test Acc: 0.9615
# test acc:  0.9615
# |  45       |  0.9615   |  6.316    |  53.42    |
# [157.3973755948033, 9.03861902078849]
# run_params: {'n': 157, 'm': 9} Train Acc: 1.0 Test Acc: 0.9565
# test acc:  0.9565
# |  46       |  0.9565   |  9.039    |  157.4    |
# [132.77335052652998, 1.0920727858828516]
# run_params: {'n': 132, 'm': 1} Train Acc: 1.0 Test Acc: 0.953
# test acc:  0.953
# |  47       |  0.953    |  1.092    |  132.8    |
# [199.90467018008087, 1.9676417022788582]
# run_params: {'n': 199, 'm': 1} Train Acc: 1.0 Test Acc: 0.95675
# test acc:  0.95675
# |  48       |  0.9567   |  1.968    |  199.9    |
# [145.50233416156175, 6.379376913825889]
# run_params: {'n': 145, 'm': 6} Train Acc: 1.0 Test Acc: 0.96225
# test acc:  0.96225
# |  49       |  0.9623   |  6.379    |  145.5    |
# [157.9621451586392, 1.0]
# run_params: {'n': 157, 'm': 1} Train Acc: 1.0 Test Acc: 0.95525
# test acc:  0.95525
# |  50       |  0.9553   |  1.0      |  158.0    |
# [100.42689039887216, 1.24706139166069]
# run_params: {'n': 100, 'm': 1} Train Acc: 1.0 Test Acc: 0.95225
# test acc:  0.95225
# |  51       |  0.9523   |  1.247    |  100.4    |
# [46.28955241397768, 7.336216920637753]
# run_params: {'n': 46, 'm': 7} Train Acc: 1.0 Test Acc: 0.95475
# test acc:  0.95475
# |  52       |  0.9547   |  7.336    |  46.29    |
# [10.742421928520024, 1.0325737657949712]
# run_params: {'n': 10, 'm': 1} Train Acc: 0.99925 Test Acc: 0.907
# test acc:  0.907
# |  53       |  0.907    |  1.033    |  10.74    |
# [171.67913354244615, 7.398518135445179]
# run_params: {'n': 171, 'm': 7} Train Acc: 1.0 Test Acc: 0.95975
# test acc:  0.95975
# |  54       |  0.9597   |  7.399    |  171.7    |
# [67.08027344866971, 7.300844717533598]
# run_params: {'n': 67, 'm': 7} Train Acc: 1.0 Test Acc: 0.959
# test acc:  0.959
# |  55       |  0.959    |  7.301    |  67.08    |
# [179.79021081306664, 19.907880892210443]
# run_params: {'n': 179, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  56       |  0.0      |  19.91    |  179.8    |
# [182.14948694690952, 10.371150412876249]
# run_params: {'n': 182, 'm': 10} Train Acc: 1.0 Test Acc: 0.956
# test acc:  0.956
# |  57       |  0.956    |  10.37    |  182.1    |
# [11.679708001875003, 9.2893857701554]
# run_params: {'n': 11, 'm': 9} Train Acc: 0.9994375 Test Acc: 0.9405
# test acc:  0.9405
# |  58       |  0.9405   |  9.289    |  11.68    |
# [120.9434945236251, 8.499505601214429]
# run_params: {'n': 120, 'm': 8} Train Acc: 1.0 Test Acc: 0.9565
# test acc:  0.9565
# |  59       |  0.9565   |  8.5      |  120.9    |
# [177.1255652363509, 6.444310538584212]
# run_params: {'n': 177, 'm': 6} Train Acc: 1.0 Test Acc: 0.96275
# test acc:  0.96275
# |  60       |  0.9627   |  6.444    |  177.1    |
# [85.80668896651953, 6.963285258476632]
# run_params: {'n': 85, 'm': 6} Train Acc: 1.0 Test Acc: 0.962
# test acc:  0.962
# |  61       |  0.962    |  6.963    |  85.81    |
# [150.7182669944286, 10.337910319681672]
# run_params: {'n': 150, 'm': 10} Train Acc: 1.0 Test Acc: 0.95675
# test acc:  0.95675
# |  62       |  0.9567   |  10.34    |  150.7    |
# [55.7588634641399, 1.0]
# run_params: {'n': 55, 'm': 1} Train Acc: 1.0 Test Acc: 0.94925
# test acc:  0.94925
# |  63       |  0.9493   |  1.0      |  55.76    |
# [108.02743832165896, 8.695141269424496]
# run_params: {'n': 108, 'm': 8} Train Acc: 1.0 Test Acc: 0.957
# test acc:  0.957
# |  64       |  0.957    |  8.695    |  108.0    |
# [75.86233104324653, 1.0]
# run_params: {'n': 75, 'm': 1} Train Acc: 1.0 Test Acc: 0.952
# test acc:  0.952
# |  65       |  0.952    |  1.0      |  75.86    |
# [31.378365925883536, 7.304892174891772]
# run_params: {'n': 31, 'm': 7} Train Acc: 1.0 Test Acc: 0.95375
# test acc:  0.95375
# |  66       |  0.9537   |  7.305    |  31.38    |
# [23.472800368770177, 6.425409616143517]
# run_params: {'n': 23, 'm': 6} Train Acc: 1.0 Test Acc: 0.95725
# test acc:  0.95725
# |  67       |  0.9573   |  6.425    |  23.47    |
# [190.17170283084866, 14.9382875779256]
# run_params: {'n': 190, 'm': 14} Train Acc: 1.0 Test Acc: 0.9455
# test acc:  0.9455
# |  68       |  0.9455   |  14.94    |  190.2    |
# [126.5969307660168, 1.0]
# run_params: {'n': 126, 'm': 1} Train Acc: 1.0 Test Acc: 0.95375
# test acc:  0.95375
# |  69       |  0.9537   |  1.0      |  126.6    |
# [166.78235353229118, 1.0]
# run_params: {'n': 166, 'm': 1} Train Acc: 1.0 Test Acc: 0.95575
# test acc:  0.95575
# |  70       |  0.9557   |  1.0      |  166.8    |
# [116.02096673910826, 12.847270976528174]
# run_params: {'n': 116, 'm': 12} Train Acc: 1.0 Test Acc: 0.95
# test acc:  0.95
# |  71       |  0.95     |  12.85    |  116.0    |
# [33.82588913148458, 1.026695891012387]
# run_params: {'n': 33, 'm': 1} Train Acc: 1.0 Test Acc: 0.94525
# test acc:  0.94525
# |  72       |  0.9453   |  1.027    |  33.83    |
# [146.85656842749813, 1.0236182610893496]
# run_params: {'n': 146, 'm': 1} Train Acc: 1.0 Test Acc: 0.955
# test acc:  0.955
# |  73       |  0.955    |  1.024    |  146.9    |
# [41.877391232444445, 1.0]
# run_params: {'n': 41, 'm': 1} Train Acc: 1.0 Test Acc: 0.947
# test acc:  0.947
# |  74       |  0.947    |  1.0      |  41.88    |
# [114.82636813515771, 1.0243130695399598]
# run_params: {'n': 114, 'm': 1} Train Acc: 1.0 Test Acc: 0.95325
# test acc:  0.95325
# |  75       |  0.9533   |  1.024    |  114.8    |
# [17.254561877911357, 8.97934288700488]
# run_params: {'n': 17, 'm': 8} Train Acc: 0.999875 Test Acc: 0.947
# test acc:  0.947
# |  76       |  0.947    |  8.979    |  17.25    |
# [185.9227033166709, 1.054135922755707]
# run_params: {'n': 185, 'm': 1} Train Acc: 1.0 Test Acc: 0.9555
# test acc:  0.9555
# |  77       |  0.9555   |  1.054    |  185.9    |
# [58.22781675438521, 9.774272272658072]
# run_params: {'n': 58, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# |  78       |  0.9543   |  9.774    |  58.23    |
# [179.30984247499907, 1.2809267185424844]
# run_params: {'n': 179, 'm': 1} Train Acc: 1.0 Test Acc: 0.95625
# test acc:  0.95625
# |  79       |  0.9563   |  1.281    |  179.3    |
# [98.64478896295658, 11.26826600566798]
# run_params: {'n': 98, 'm': 11} Train Acc: 1.0 Test Acc: 0.9525
# test acc:  0.9525
# |  80       |  0.9525   |  11.27    |  98.64    |
# [93.27268715774083, 16.247529914803245]
# run_params: {'n': 93, 'm': 16} Train Acc: 1.0 Test Acc: 0.93725
# test acc:  0.93725
# |  81       |  0.9373   |  16.25    |  93.27    |
# [22.473418774745753, 1.242726175842686]
# run_params: {'n': 22, 'm': 1} Train Acc: 0.999875 Test Acc: 0.93625
# test acc:  0.93625
# |  82       |  0.9363   |  1.243    |  22.47    |
# [87.7102351156238, 1.5911342341460046]
# run_params: {'n': 87, 'm': 1} Train Acc: 1.0 Test Acc: 0.95225
# test acc:  0.95225
# |  83       |  0.9523   |  1.591    |  87.71    |
# [6.181042635734921, 6.633901836732568]
# run_params: {'n': 6, 'm': 6} Train Acc: 0.996125 Test Acc: 0.9235
# test acc:  0.9235
# |  84       |  0.9235   |  6.634    |  6.181    |
# [80.54841628635545, 5.749470806495175]
# run_params: {'n': 80, 'm': 5} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# |  85       |  0.9625   |  5.749    |  80.55    |
# [186.51933442454526, 13.261921557463959]
# run_params: {'n': 186, 'm': 13} Train Acc: 1.0 Test Acc: 0.95025
# test acc:  0.95025
# |  86       |  0.9503   |  13.26    |  186.5    |
# [192.00074502478114, 5.564560844986136]
# run_params: {'n': 192, 'm': 5} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# |  87       |  0.964    |  5.565    |  192.0    |
# [189.11082281999327, 19.8651532959276]
# run_params: {'n': 189, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  88       |  0.0      |  19.87    |  189.1    |
# [192.46677919407225, 11.266573338939038]
# run_params: {'n': 192, 'm': 11} Train Acc: 1.0 Test Acc: 0.95475
# test acc:  0.95475
# |  89       |  0.9547   |  11.27    |  192.5    |
# [136.28759255436134, 13.842859592350964]
# run_params: {'n': 136, 'm': 13} Train Acc: 1.0 Test Acc: 0.9515
# test acc:  0.9515
# |  90       |  0.9515   |  13.84    |  136.3    |
# [13.18741244299528, 19.88681472732543]
# run_params: {'n': 13, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  91       |  0.0      |  19.89    |  13.19    |
# [74.88855449073367, 12.030514524164932]
# run_params: {'n': 74, 'm': 12} Train Acc: 1.0 Test Acc: 0.95025
# test acc:  0.95025
# |  92       |  0.9503   |  12.03    |  74.89    |
# [165.0966620181763, 9.732615718378742]
# run_params: {'n': 165, 'm': 9} Train Acc: 1.0 Test Acc: 0.95625
# test acc:  0.95625
# |  93       |  0.9563   |  9.733    |  165.1    |
# [96.70799168648125, 5.377720745950773]
# run_params: {'n': 96, 'm': 5} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# |  94       |  0.9625   |  5.378    |  96.71    |
# [12.476578218763379, 5.480951086065574]
# run_params: {'n': 12, 'm': 5} Train Acc: 0.999625 Test Acc: 0.94475
# test acc:  0.94475
# |  95       |  0.9447   |  5.481    |  12.48    |
# [132.28254865137936, 10.786885853257642]
# run_params: {'n': 132, 'm': 10} Train Acc: 1.0 Test Acc: 0.95525
# test acc:  0.95525
# |  96       |  0.9553   |  10.79    |  132.3    |
# [1.0, 8.737560718643412]
# run_params: {'n': 1, 'm': 8} Train Acc: 0.9454375 Test Acc: 0.85425
# test acc:  0.85425
# |  97       |  0.8542   |  8.738    |  1.0      |
# [158.74385496326065, 13.373562179526502]
# run_params: {'n': 158, 'm': 13} Train Acc: 1.0 Test Acc: 0.95175
# test acc:  0.95175
# |  98       |  0.9517   |  13.37    |  158.7    |
# [152.75285771309208, 1.0]
# run_params: {'n': 152, 'm': 1} Train Acc: 1.0 Test Acc: 0.9545
# test acc:  0.9545
# |  99       |  0.9545   |  1.0      |  152.8    |
# [63.500043896885984, 1.0]
# run_params: {'n': 63, 'm': 1} Train Acc: 1.0 Test Acc: 0.951
# test acc:  0.951
# |  100      |  0.951    |  1.0      |  63.5     |
# [70.94726203133774, 8.29076315815655]
# run_params: {'n': 70, 'm': 8} Train Acc: 1.0 Test Acc: 0.9545
# test acc:  0.9545
# |  101      |  0.9545   |  8.291    |  70.95    |
# [71.73371526118311, 19.692256894018715]
# run_params: {'n': 71, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  102      |  0.0      |  19.69    |  71.73    |
# [124.17374540257738, 4.945214195817243]
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# |  103      |  0.964    |  4.945    |  124.2    |
# [63.55772113313316, 10.00384803056181]
# run_params: {'n': 63, 'm': 10} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# |  104      |  0.9543   |  10.0     |  63.56    |
# [140.43054846863274, 10.791466943761906]
# run_params: {'n': 140, 'm': 10} Train Acc: 1.0 Test Acc: 0.95625
# test acc:  0.95625
# |  105      |  0.9563   |  10.79    |  140.4    |
# [118.39611754089275, 5.0294640971347295]
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# |  106      |  0.9637   |  5.029    |  118.4    |
# [199.94984127343443, 8.348727445768382]
# run_params: {'n': 199, 'm': 8} Train Acc: 1.0 Test Acc: 0.95725
# test acc:  0.95725
# |  107      |  0.9573   |  8.349    |  199.9    |
# [112.36186178460963, 10.748711006184074]
# run_params: {'n': 112, 'm': 10} Train Acc: 1.0 Test Acc: 0.9575
# test acc:  0.9575
# |  108      |  0.9575   |  10.75    |  112.4    |
# [104.99896600007433, 4.32006161735846]
# run_params: {'n': 104, 'm': 4} Train Acc: 1.0 Test Acc: 0.96425
# test acc:  0.96425
# |  109      |  0.9643   |  4.32     |  105.0    |
# [90.4909351636687, 6.320186265274379]
# run_params: {'n': 90, 'm': 6} Train Acc: 1.0 Test Acc: 0.962
# test acc:  0.962
# |  110      |  0.962    |  6.32     |  90.49    |
# [167.77153551890297, 5.423951463590789]
# run_params: {'n': 167, 'm': 5} Train Acc: 1.0 Test Acc: 0.96275
# test acc:  0.96275
# |  111      |  0.9627   |  5.424    |  167.8    |
# [50.90822888210734, 9.427158830467668]
# run_params: {'n': 50, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# |  112      |  0.9543   |  9.427    |  50.91    |
# [42.8374539525614, 5.105888679864311]
# run_params: {'n': 42, 'm': 5} Train Acc: 1.0 Test Acc: 0.95875
# test acc:  0.95875
# |  113      |  0.9587   |  5.106    |  42.84    |
# [79.07283584279638, 9.798255384564468]
# run_params: {'n': 79, 'm': 9} Train Acc: 1.0 Test Acc: 0.954
# test acc:  0.954
# |  114      |  0.954    |  9.798    |  79.07    |
# [133.90205375689, 5.600970314869148]
# run_params: {'n': 133, 'm': 5} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# |  115      |  0.9635   |  5.601    |  133.9    |
# [27.74852148401645, 5.073509517542807]
# run_params: {'n': 27, 'm': 5} Train Acc: 1.0 Test Acc: 0.956
# test acc:  0.956
# |  116      |  0.956    |  5.074    |  27.75    |
# [110.50742536387806, 4.049698262953925]
# run_params: {'n': 110, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# |  117      |  0.9635   |  4.05     |  110.5    |
# [94.85907263503671, 19.798660333186902]
# run_params: {'n': 94, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  118      |  0.0      |  19.8     |  94.86    |
# [89.43291170048931, 12.679023343123307]
# run_params: {'n': 89, 'm': 12} Train Acc: 1.0 Test Acc: 0.95075
# test acc:  0.95075
# |  119      |  0.9507   |  12.68    |  89.43    |
# [94.95312990062128, 13.932593832146127]
# run_params: {'n': 94, 'm': 13} Train Acc: 1.0 Test Acc: 0.94975
# test acc:  0.94975
# |  120      |  0.9497   |  13.93    |  94.95    |
# [103.85636249432852, 12.021589821606431]
# run_params: {'n': 103, 'm': 12} Train Acc: 1.0 Test Acc: 0.94975
# test acc:  0.94975
# |  121      |  0.9497   |  12.02    |  103.9    |
# [34.66691522571497, 10.905168147091835]
# run_params: {'n': 34, 'm': 10} Train Acc: 1.0 Test Acc: 0.952
# test acc:  0.952
# |  122      |  0.952    |  10.91    |  34.67    |
# [115.14545630516487, 18.683110629497033]
# run_params: {'n': 115, 'm': 18} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  123      |  0.0      |  18.68    |  115.1    |
# [171.463266203816, 11.560220495064762]
# run_params: {'n': 171, 'm': 11} Train Acc: 1.0 Test Acc: 0.9545
# test acc:  0.9545
# |  124      |  0.9545   |  11.56    |  171.5    |
# [187.60021112096751, 4.846597441947212]
# run_params: {'n': 187, 'm': 4} Train Acc: 1.0 Test Acc: 0.96275
# test acc:  0.96275
# |  125      |  0.9627   |  4.847    |  187.6    |
# [136.0448573990384, 19.556866615111915]
# run_params: {'n': 136, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  126      |  0.0      |  19.56    |  136.0    |
# [116.7732079477825, 9.170942844048911]
# run_params: {'n': 116, 'm': 9} Train Acc: 1.0 Test Acc: 0.95625
# test acc:  0.95625
# |  127      |  0.9563   |  9.171    |  116.8    |
# [126.19653858501114, 9.641347256606187]
# run_params: {'n': 126, 'm': 9} Train Acc: 1.0 Test Acc: 0.9555
# test acc:  0.9555
# |  128      |  0.9555   |  9.641    |  126.2    |
# [196.16989696462392, 1.105186653089965]
# run_params: {'n': 196, 'm': 1} Train Acc: 1.0 Test Acc: 0.9555
# test acc:  0.9555
# |  129      |  0.9555   |  1.105    |  196.2    |
# [137.1555022542263, 1.1241611772093294]
# run_params: {'n': 137, 'm': 1} Train Acc: 1.0 Test Acc: 0.95475
# test acc:  0.95475
# |  130      |  0.9547   |  1.124    |  137.2    |
# [19.536730402350234, 5.523905598007779]
# run_params: {'n': 19, 'm': 5} Train Acc: 0.9999375 Test Acc: 0.951
# test acc:  0.951
# |  131      |  0.951    |  5.524    |  19.54    |
# [175.48172437367478, 9.539086975563913]
# run_params: {'n': 175, 'm': 9} Train Acc: 1.0 Test Acc: 0.9565
# test acc:  0.9565
# |  132      |  0.9565   |  9.539    |  175.5    |
# [54.554475761559, 11.527344278547728]
# run_params: {'n': 54, 'm': 11} Train Acc: 1.0 Test Acc: 0.94975
# test acc:  0.94975
# |  133      |  0.9497   |  11.53    |  54.55    |
# [162.26005663273784, 1.0]
# run_params: {'n': 162, 'm': 1} Train Acc: 1.0 Test Acc: 0.9545
# test acc:  0.9545
# |  134      |  0.9545   |  1.0      |  162.3    |
# [154.9811504512301, 11.978597993682758]
# run_params: {'n': 154, 'm': 11} Train Acc: 1.0 Test Acc: 0.9545
# test acc:  0.9545
# |  135      |  0.9545   |  11.98    |  155.0    |
# [96.36201607453998, 1.1117814087480642]
# run_params: {'n': 96, 'm': 1} Train Acc: 1.0 Test Acc: 0.95275
# test acc:  0.95275
# |  136      |  0.9527   |  1.112    |  96.36    |
# [136.05321034881274, 10.91187117756988]
# run_params: {'n': 136, 'm': 10} Train Acc: 1.0 Test Acc: 0.9555
# test acc:  0.9555
# |  137      |  0.9555   |  10.91    |  136.1    |
# [141.2174529172984, 5.343963188844834]
# run_params: {'n': 141, 'm': 5} Train Acc: 1.0 Test Acc: 0.9645
# test acc:  0.9645
# |  138      |  0.9645   |  5.344    |  141.2    |
# [157.91312568629098, 4.695636415961329]
# run_params: {'n': 157, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# |  139      |  0.9635   |  4.696    |  157.9    |
# [52.02227680244047, 1.2575775587624367]
# run_params: {'n': 52, 'm': 1} Train Acc: 1.0 Test Acc: 0.9485
# test acc:  0.9485
# |  140      |  0.9485   |  1.258    |  52.02    |
# [161.47227993659965, 8.960105712613053]
# run_params: {'n': 161, 'm': 8} Train Acc: 1.0 Test Acc: 0.9585
# test acc:  0.9585
# |  141      |  0.9585   |  8.96     |  161.5    |
# [34.96554654320376, 7.598206984884944]
# run_params: {'n': 34, 'm': 7} Train Acc: 1.0 Test Acc: 0.954
# test acc:  0.954
# |  142      |  0.954    |  7.598    |  34.97    |
# [182.95797777027408, 14.204661490634372]
# run_params: {'n': 182, 'm': 14} Train Acc: 1.0 Test Acc: 0.94525
# test acc:  0.94525
# |  143      |  0.9453   |  14.2     |  183.0    |
# [199.94612091860395, 5.534837299257255]
# run_params: {'n': 199, 'm': 5} Train Acc: 1.0 Test Acc: 0.9645
# test acc:  0.9645
# |  144      |  0.9645   |  5.535    |  199.9    |
# [57.487561312395925, 5.8438099441219755]
# run_params: {'n': 57, 'm': 5} Train Acc: 1.0 Test Acc: 0.96225
# test acc:  0.96225
# |  145      |  0.9623   |  5.844    |  57.49    |
# [156.86033971793026, 19.338400701477486]
# run_params: {'n': 156, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# |  146      |  0.0      |  19.34    |  156.9    |
# [49.194552039261865, 4.865710757305054]
# run_params: {'n': 49, 'm': 4} Train Acc: 1.0 Test Acc: 0.96025
# test acc:  0.96025
# |  147      |  0.9603   |  4.866    |  49.19    |
# [6.320537983270201, 10.636319725132411]
# run_params: {'n': 6, 'm': 10} Train Acc: 0.996 Test Acc: 0.922
# test acc:  0.922
# |  148      |  0.922    |  10.64    |  6.321    |
# [146.82272798467292, 9.999541917849688]
# run_params: {'n': 146, 'm': 9} Train Acc: 1.0 Test Acc: 0.9555
# test acc:  0.9555
# |  149      |  0.9555   |  10.0     |  146.8    |
# [27.982380620951574, 9.328105034187713]
# run_params: {'n': 27, 'm': 9} Train Acc: 1.0 Test Acc: 0.951
# test acc:  0.951
# |  150      |  0.951    |  9.328    |  27.98    |
# =================================================
# Time to execute: 616.7236 seconds
# {'target': 0.9645, 'params': {'max_features': 5.343963188844834, 'n_estimators': 141.2174529172984}}
