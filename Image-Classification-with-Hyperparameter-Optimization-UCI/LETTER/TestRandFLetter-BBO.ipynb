# %%
import numpy as np # linear algebra
import pandas as pd # data processing, 
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# importing Random Forest classifier
from sklearn.ensemble import RandomForestClassifier


import os
from pathlib import Path
import time
from collections import OrderedDict, namedtuple

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

# %%
if IN_COLAB:

    from google.colab import drive
    drive.mount('/drive', force_remount=True)
    datadir = '/drive/My Drive/Colab Notebooks/Datasets/'
    optim_dir = datadir + '/optim_dir/'
    results_folder = datadir+'/results/UCI/'
    Path(results_folder).mkdir(parents=True, exist_ok=True)
    Path(optim_dir).mkdir(parents=True, exist_ok=True)
else:
  results_folder = 'results'
  optim_dir = 'optim_dir'
  Path("results").mkdir(parents=True, exist_ok=True)
  Path(optim_dir).mkdir(parents=True, exist_ok=True)


# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO
# Out:
# Mounted at /drive

# %%
import sys

# !pip install category_encoders
import category_encoders as ce

if IN_COLAB:
  
  scripts_dir = '/drive/My Drive/Colab Notebooks/scripts/'
  sys.path.insert(1, scripts_dir)
# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO

# insert at 1, 0 is the script path (or '' in REPL)
else:
    sys.path.insert(1, 'scripts')
from BBO import BaseBBO
import pickle
# Out:
# Collecting category_encoders
#   Downloading https://files.pythonhosted.org/packages/44/57/fcef41c248701ee62e8325026b90c432adea35555cbc870aff9cfba23727/category_encoders-2.2.2-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 4.1MB/s
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.1.5)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.2.2

# %%
# Enable GPU processing
# if IN_COLAB:
#     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# else:
#     device = torch.device("cpu")
# print(f'Device type: {device}')

# %%
# Set random seed
seed = 777
# torch.manual_seed(seed)
model = None

# %%
import random
def seeding(SEED):
    np.random.seed(SEED)
    random.seed(SEED)
    os.environ['PYTHONHASHSEED'] = str(SEED)
    os.environ['TF_CUDNN_DETERMINISTIC'] = str(SEED)
    # tf.random.set_seed(SEED)
    print('seeding done!!!')
seeding(seed)
# Out:
# seeding done!!!

# %%
df = pd.read_csv(f"{datadir}UCI/Letter/data.csv")

# %%
df.head()
# Out:
#   letter  xbox   ybox   width   height  ...  xy2bar  xedge   xedgey  yedge   yedgex
# 0      T      2      8       3       5  ...       8       0       8       0       8
# 1      I      5     12       3       7  ...       9       2       8       4      10
# 2      D      4     11       6       8  ...       7       3       7       3       9
# 3      N      7     11       6       6  ...      10       6      10       2       8
# 4      G      2      1       3       1  ...       9       1       7       5      10
#
# [5 rows x 17 columns]

# %%
df.shape
# Out:
# (20000, 17)

# %%
x = df.drop(['letter'], axis=1)
y = df['letter']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 42) # Split dataset into train and test sets

# %%
X_train.shape, X_test.shape # Get the dimensions of features
# Out:
# ((16000, 16), (4000, 16))

# %%
X_train.head()
# Out:
#       xbox   ybox   width   height  ...  xedge   xedgey  yedge   yedgex
# 5894      4      7       5       5  ...       3       8       4       8
# 3728      4      7       6       5  ...       3       8       4       7
# 8958      3      5       4       3  ...       5       9       2       6
# 7671      4     10       6       7  ...       3       8       6       9
# 5999      4     10       6       8  ...       3      11       1       8
#
# [5 rows x 16 columns]

# %%
# Create a class to manage the training / hyperparameter runs
class RunManager():
  def __init__(self):
    self.run_params = None
    self.run_count = 0
    self.run_data = []
    
    #---
    self.results = None

  def begin_run(self, run):
    self.run_params = run
    self.run_count += 1
    

  def end_run(self, train_accuracy, test_accuracy):
    # self.epoch_count = 0
    # train_accuracy = 
    # test_accuracy = 

    print(f'run_params: {self.run_params} Train Acc: {train_accuracy} Test Acc: {test_accuracy}')

    results = OrderedDict()
    results['run'] = self.run_count
    results['train acc'] = train_accuracy
    results['test acc'] = test_accuracy
    
    # ---
    self.results = results

    for k, v in self.run_params.items():
      results[k] = v

    self.run_data.append(results)

  def save_output(self, filename):
    if filename:
      filename = filename
      pd.DataFrame.from_dict(self.run_data, orient='columns').to_csv(f'{filename}.csv')
      
      # with open(f'{filename}.json', 'w', encoding='utf-8') as f:
      #   json.dump(self.run_data, f, ensure_ascii=False, indent=4)

      # print('Results saved to disk')

    return pd.DataFrame.from_dict(self.run_data, orient='columns')

# %%
# Define training loop execution
def execution_loop(m, args): # args is given by the optimizer
    agent = {}
    agents = []
    
    agent['n'] = args[0].astype(int)
    agent['m'] = int(args[1])
    agents.append(agent)
#     m = RunManager()
    for run in agents: # this should be one. a particle in pso

        # print(f'Run Params: {run}')

        m.begin_run(run)

        num_predictors = X_train.shape[1]
        if run['m'] <= num_predictors:

          rfc = RandomForestClassifier(n_estimators=run['n'], max_features=run['m'], random_state=0)
          rfc.fit(X_train, y_train)

          y_pred_train = rfc.predict(X_train)
          y_pred_test = rfc.predict(X_test)

          train_score = accuracy_score(y_train, y_pred_train)
          test_score = accuracy_score(y_test, y_pred_test)
        else:
          train_score = 0
          test_score = 0

        m.end_run(train_score, test_score)
    return m.results['test acc']

# %%
# Define training run hyperparameters
params = {
    'n' : [1, 200],
    'm' : [1, 20]
}

# params = OrderedDict(
#     lr = [0, 1],
#     batch_size = [20 2000],
#     n_epochs = [3]
# )

# %%
m = RunManager()
timestr = time.strftime("%Y%m%d-%H%M%S")
filename = f'Run_Results-UCI-Letter-BBO-{timestr}'
# filename = 'Run_Results-PSO-20210504-035642-cont.csv' # this is for trying to continue from last optim save

# %%
def run_train_model(agent):
    test_acc = execution_loop(m, agent)
    m.save_output(f'{results_folder}/{filename}')
    print("test acc: ", test_acc)
    return test_acc * -1

# %%
verbose = True
pop_size = 15   
max_iter = 10

obj_func = run_train_model

lb = [params['n'][0], params['m'][0]]
ub = [params['n'][1], params['m'][1]]

tic = time.perf_counter()
md2 = BaseBBO(obj_func, lb, ub, verbose, max_iter, pop_size,0.1, 2) 
best_pos1, best_fit1, list_loss1 = md2.train(f"{optim_dir}/bbo_data-UCI-Letter-{timestr}.data")
toc = time.perf_counter()
print(f'Time to execute: {toc - tic:0.4f} seconds')
print(f'Best Position: {[int(x) for x in best_pos1]} Best Solution: {best_fit1:0.5f}')

# m.save_output(f'{results_folder}/{filename}')
# print('Results saved.')
# Out:
# run_params: {'n': 31, 'm': 6} Train Acc: 1.0 Test Acc: 0.95775
# test acc:  0.95775
# run_params: {'n': 13, 'm': 9} Train Acc: 0.99975 Test Acc: 0.94375
# test acc:  0.94375
# run_params: {'n': 167, 'm': 18} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 145, 'm': 15} Train Acc: 1.0 Test Acc: 0.94125
# test acc:  0.94125
# run_params: {'n': 54, 'm': 13} Train Acc: 1.0 Test Acc: 0.946
# test acc:  0.946
# run_params: {'n': 19, 'm': 2} Train Acc: 1.0 Test Acc: 0.946
# test acc:  0.946
# run_params: {'n': 118, 'm': 7} Train Acc: 1.0 Test Acc: 0.9595
# test acc:  0.9595
# run_params: {'n': 197, 'm': 12} Train Acc: 1.0 Test Acc: 0.952
# test acc:  0.952
# run_params: {'n': 136, 'm': 11} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 54, 'm': 8} Train Acc: 1.0 Test Acc: 0.954
# test acc:  0.954
# run_params: {'n': 45, 'm': 4} Train Acc: 1.0 Test Acc: 0.961
# test acc:  0.961
# run_params: {'n': 78, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# run_params: {'n': 122, 'm': 17} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 36, 'm': 16} Train Acc: 1.0 Test Acc: 0.9355
# test acc:  0.9355
# run_params: {'n': 120, 'm': 6} Train Acc: 1.0 Test Acc: 0.9615
# test acc:  0.9615
# run_params: {'n': 13, 'm': 9} Train Acc: 0.99975 Test Acc: 0.94375
# test acc:  0.94375
# run_params: {'n': 167, 'm': 18} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 145, 'm': 15} Train Acc: 1.0 Test Acc: 0.94125
# test acc:  0.94125
# run_params: {'n': 66, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 19, 'm': 2} Train Acc: 1.0 Test Acc: 0.946
# test acc:  0.946
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 197, 'm': 8} Train Acc: 1.0 Test Acc: 0.95675
# test acc:  0.95675
# run_params: {'n': 136, 'm': 15} Train Acc: 1.0 Test Acc: 0.94075
# test acc:  0.94075
# run_params: {'n': 145, 'm': 8} Train Acc: 1.0 Test Acc: 0.958
# test acc:  0.958
# run_params: {'n': 45, 'm': 9} Train Acc: 1.0 Test Acc: 0.95325
# test acc:  0.95325
# run_params: {'n': 145, 'm': 15} Train Acc: 1.0 Test Acc: 0.94125
# test acc:  0.94125
# run_params: {'n': 66, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 197, 'm': 8} Train Acc: 1.0 Test Acc: 0.95675
# test acc:  0.95675
# run_params: {'n': 197, 'm': 16} Train Acc: 1.0 Test Acc: 0.9385
# test acc:  0.9385
# > Epoch: 2, Best fit: -0.96375
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 78, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# run_params: {'n': 66, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 145, 'm': 2} Train Acc: 1.0 Test Acc: 0.962
# test acc:  0.962
# run_params: {'n': 197, 'm': 16} Train Acc: 1.0 Test Acc: 0.9385
# test acc:  0.9385
# run_params: {'n': 66, 'm': 8} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 66, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 66, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 124, 'm': 9} Train Acc: 1.0 Test Acc: 0.956
# test acc:  0.956
# run_params: {'n': 197, 'm': 16} Train Acc: 1.0 Test Acc: 0.9385
# test acc:  0.9385
# run_params: {'n': 197, 'm': 16} Train Acc: 1.0 Test Acc: 0.9385
# test acc:  0.9385
# run_params: {'n': 75, 'm': 5} Train Acc: 1.0 Test Acc: 0.96225
# test acc:  0.96225
# run_params: {'n': 78, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# run_params: {'n': 78, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# > Epoch: 3, Best fit: -0.96375
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 91, 'm': 5} Train Acc: 1.0 Test Acc: 0.961
# test acc:  0.961
# run_params: {'n': 58, 'm': 5} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# run_params: {'n': 15, 'm': 4} Train Acc: 0.999875 Test Acc: 0.948
# test acc:  0.948
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 58, 'm': 5} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# run_params: {'n': 66, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 66, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 66, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 91, 'm': 8} Train Acc: 1.0 Test Acc: 0.95375
# test acc:  0.95375
# run_params: {'n': 58, 'm': 5} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# run_params: {'n': 124, 'm': 8} Train Acc: 1.0 Test Acc: 0.95625
# test acc:  0.95625
# run_params: {'n': 91, 'm': 5} Train Acc: 1.0 Test Acc: 0.961
# test acc:  0.961
# > Epoch: 4, Best fit: -0.964
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 58, 'm': 1} Train Acc: 1.0 Test Acc: 0.94925
# test acc:  0.94925
# run_params: {'n': 58, 'm': 18} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 118, 'm': 14} Train Acc: 1.0 Test Acc: 0.945
# test acc:  0.945
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# > Epoch: 5, Best fit: -0.964
# run_params: {'n': 124, 'm': 7} Train Acc: 1.0 Test Acc: 0.96025
# test acc:  0.96025
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 118, 'm': 3} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 91, 'm': 9} Train Acc: 1.0 Test Acc: 0.955
# test acc:  0.955
# run_params: {'n': 91, 'm': 8} Train Acc: 1.0 Test Acc: 0.95375
# test acc:  0.95375
# run_params: {'n': 124, 'm': 1} Train Acc: 1.0 Test Acc: 0.9535
# test acc:  0.9535
# run_params: {'n': 91, 'm': 3} Train Acc: 1.0 Test Acc: 0.95975
# test acc:  0.95975
# run_params: {'n': 91, 'm': 9} Train Acc: 1.0 Test Acc: 0.955
# test acc:  0.955
# run_params: {'n': 124, 'm': 7} Train Acc: 1.0 Test Acc: 0.96025
# test acc:  0.96025
# run_params: {'n': 118, 'm': 1} Train Acc: 1.0 Test Acc: 0.954
# test acc:  0.954
# > Epoch: 6, Best fit: -0.964
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 118, 'm': 18} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 124, 'm': 7} Train Acc: 1.0 Test Acc: 0.96025
# test acc:  0.96025
# run_params: {'n': 124, 'm': 7} Train Acc: 1.0 Test Acc: 0.96025
# test acc:  0.96025
# run_params: {'n': 118, 'm': 2} Train Acc: 1.0 Test Acc: 0.9615
# test acc:  0.9615
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 64, 'm': 9} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 118, 'm': 18} Train Acc: 0 Test Acc: 0
# test acc:  0
# > Epoch: 7, Best fit: -0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 124, 'm': 13} Train Acc: 1.0 Test Acc: 0.95
# test acc:  0.95
# run_params: {'n': 124, 'm': 1} Train Acc: 1.0 Test Acc: 0.9535
# test acc:  0.9535
# run_params: {'n': 41, 'm': 4} Train Acc: 1.0 Test Acc: 0.9585
# test acc:  0.9585
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 118, 'm': 2} Train Acc: 1.0 Test Acc: 0.9615
# test acc:  0.9615
# run_params: {'n': 124, 'm': 1} Train Acc: 1.0 Test Acc: 0.9535
# test acc:  0.9535
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 124, 'm': 1} Train Acc: 1.0 Test Acc: 0.9535
# test acc:  0.9535
# run_params: {'n': 41, 'm': 4} Train Acc: 1.0 Test Acc: 0.9585
# test acc:  0.9585
# run_params: {'n': 193, 'm': 4} Train Acc: 1.0 Test Acc: 0.963
# test acc:  0.963
# > Epoch: 8, Best fit: -0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 118, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 193, 'm': 4} Train Acc: 1.0 Test Acc: 0.963
# test acc:  0.963
# run_params: {'n': 118, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# > Epoch: 9, Best fit: -0.96525
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 71, 'm': 4} Train Acc: 1.0 Test Acc: 0.96225
# test acc:  0.96225
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 11} Train Acc: 1.0 Test Acc: 0.953
# test acc:  0.953
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 91, 'm': 9} Train Acc: 1.0 Test Acc: 0.955
# test acc:  0.955
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# run_params: {'n': 91, 'm': 4} Train Acc: 1.0 Test Acc: 0.96525
# test acc:  0.96525
# run_params: {'n': 91, 'm': 2} Train Acc: 1.0 Test Acc: 0.96
# test acc:  0.96
# > Epoch: 10, Best fit: -0.96525
# Time to execute: 599.9618 seconds
# Best Position: [91, 4] Best Solution: -0.96525
