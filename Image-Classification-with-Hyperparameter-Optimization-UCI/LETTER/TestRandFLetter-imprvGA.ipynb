# %%
import numpy as np # linear algebra
import pandas as pd # data processing, 
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# importing Random Forest classifier
from sklearn.ensemble import RandomForestClassifier


import os
from pathlib import Path
import time
from collections import OrderedDict, namedtuple

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

# %%
if IN_COLAB:

    from google.colab import drive
    drive.mount('/drive', force_remount=True)
    datadir = '/drive/My Drive/Colab Notebooks/Datasets/'
    optim_dir = datadir + '/optim_dir/'
    results_folder = datadir+'/results/UCI/'
    Path(results_folder).mkdir(parents=True, exist_ok=True)
    Path(optim_dir).mkdir(parents=True, exist_ok=True)
else:
  results_folder = 'results'
  optim_dir = 'optim_dir'
  Path("results").mkdir(parents=True, exist_ok=True)
  Path(optim_dir).mkdir(parents=True, exist_ok=True)


# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO
# Out:
# Mounted at /drive

# %%
import sys

# !pip install category_encoders
import category_encoders as ce

if IN_COLAB:
  
  scripts_dir = '/drive/My Drive/Colab Notebooks/scripts/'
  sys.path.insert(1, scripts_dir)
# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO

# insert at 1, 0 is the script path (or '' in REPL)
else:
    sys.path.insert(1, 'scripts')
from geneticalgorithmOptd import geneticalgorithmOptd as gaOptd
import pickle
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.7/dist-packages (2.2.2)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.1.5)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.19.5)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)

# %%
# Enable GPU processing
# if IN_COLAB:
#     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# else:
#     device = torch.device("cpu")
# print(f'Device type: {device}')

# %%
# Set random seed
seed = 777
# torch.manual_seed(seed)
model = None

# %%
import random
def seeding(SEED):
    np.random.seed(SEED)
    random.seed(SEED)
    os.environ['PYTHONHASHSEED'] = str(SEED)
    os.environ['TF_CUDNN_DETERMINISTIC'] = str(SEED)
    # tf.random.set_seed(SEED)
    print('seeding done!!!')
seeding(seed)
# Out:
# seeding done!!!

# %%
df = pd.read_csv(f"{datadir}UCI/Letter/data.csv")

# %%
df.head()
# Out:
#   letter  xbox   ybox   width   height  ...  xy2bar  xedge   xedgey  yedge   yedgex
# 0      T      2      8       3       5  ...       8       0       8       0       8
# 1      I      5     12       3       7  ...       9       2       8       4      10
# 2      D      4     11       6       8  ...       7       3       7       3       9
# 3      N      7     11       6       6  ...      10       6      10       2       8
# 4      G      2      1       3       1  ...       9       1       7       5      10
#
# [5 rows x 17 columns]

# %%
df.shape
# Out:
# (20000, 17)

# %%
x = df.drop(['letter'], axis=1)
y = df['letter']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 42) # Split dataset into train and test sets

# %%
X_train.shape, X_test.shape # Get the dimensions of features
# Out:
# ((16000, 16), (4000, 16))

# %%
X_train.head()
# Out:
#       xbox   ybox   width   height  ...  xedge   xedgey  yedge   yedgex
# 5894      4      7       5       5  ...       3       8       4       8
# 3728      4      7       6       5  ...       3       8       4       7
# 8958      3      5       4       3  ...       5       9       2       6
# 7671      4     10       6       7  ...       3       8       6       9
# 5999      4     10       6       8  ...       3      11       1       8
#
# [5 rows x 16 columns]

# %%
# Create a class to manage the training / hyperparameter runs
class RunManager():
  def __init__(self):
    self.run_params = None
    self.run_count = 0
    self.run_data = []
    
    #---
    self.results = None

  def begin_run(self, run):
    self.run_params = run
    self.run_count += 1
    

  def end_run(self, train_accuracy, test_accuracy):
    # self.epoch_count = 0
    # train_accuracy = 
    # test_accuracy = 

    print(f'run_params: {self.run_params} Train Acc: {train_accuracy} Test Acc: {test_accuracy}')

    results = OrderedDict()
    results['run'] = self.run_count
    results['train acc'] = train_accuracy
    results['test acc'] = test_accuracy
    
    # ---
    self.results = results

    for k, v in self.run_params.items():
      results[k] = v

    self.run_data.append(results)

  def save_output(self, filename):
    if filename:
      filename = filename
      pd.DataFrame.from_dict(self.run_data, orient='columns').to_csv(f'{filename}.csv')
      
      # with open(f'{filename}.json', 'w', encoding='utf-8') as f:
      #   json.dump(self.run_data, f, ensure_ascii=False, indent=4)

      # print('Results saved to disk')

    return pd.DataFrame.from_dict(self.run_data, orient='columns')

# %%
# Define training loop execution
def execution_loop(m, args): # args is given by the optimizer
    agent = {}
    agents = []
    
    agent['n'] = args[0].astype(int)
    agent['m'] = int(args[1])
    agents.append(agent)
#     m = RunManager()
    for run in agents: # this should be one. a particle in pso

        # print(f'Run Params: {run}')

        m.begin_run(run)

        num_predictors = X_train.shape[1]
        if run['m'] <= num_predictors:

          rfc = RandomForestClassifier(n_estimators=run['n'], max_features=run['m'], random_state=0)
          rfc.fit(X_train, y_train)

          y_pred_train = rfc.predict(X_train)
          y_pred_test = rfc.predict(X_test)

          train_score = accuracy_score(y_train, y_pred_train)
          test_score = accuracy_score(y_test, y_pred_test)
        else:
          train_score = 0
          test_score = 0

        m.end_run(train_score, test_score)
    return m.results['test acc']

# %%
# Define training run hyperparameters
params = {
    'n' : [1, 200],
    'm' : [1, 20]
}

# params = OrderedDict(
#     lr = [0, 1],
#     batch_size = [20 2000],
#     n_epochs = [3]
# )

# %%
m = RunManager()
timestr = time.strftime("%Y%m%d-%H%M%S")
filename = f'Run_Results-UCI-Letter-imprvGA-{timestr}'
# filename = 'Run_Results-PSO-20210504-035642-cont.csv' # this is for trying to continue from last optim save

# %%
def run_train_model(agent):
    test_acc = execution_loop(m, agent)
    m.save_output(f'{results_folder}/{filename}')
    print("test acc: ", test_acc)
    return test_acc * -1

# %%
verbose = True
pop_size = 15   
max_iter = 10

obj_func = run_train_model

lb = [params['n'][0], params['m'][0]]
ub = [params['n'][1], params['m'][1]]

algorithm_param = {'max_num_iteration': max_iter,\
                   'population_size':pop_size,\
                   'mutation_probability':0.5,\
                   'elit_ratio': 0.1,\
                   'crossover_probability': 0.7,\
                   'parents_portion': 0.3,\
                   'crossover_type':'uniform',\
                   'max_iteration_without_improv':None}

varbound = np.array([ [ lb[0], ub[0] ], [ lb[1], ub[1] ] ] )

tic = time.perf_counter() # Start time counter
model=gaOptd(function=obj_func,dimension=2,variable_type='real',variable_boundaries=varbound, algorithm_parameters=algorithm_param, function_timeout=1000)
model.run(f"{optim_dir}/ga_data-UCI-imprvGA-{timestr}.data")

toc = time.perf_counter() # End time counter
print(f'Time to execute: {toc - tic:0.4f} seconds')
print(f'Best Position: {[int(x) for x in model.best_variable]} Best Solution: {model.best_function:0.5f}')

# m.save_output(f'{results_folder}/{filename}')
# print('Results saved.')
# Out:
# run_params: {'n': 31, 'm': 6} Train Acc: 1.0 Test Acc: 0.95775
# test acc:  0.95775
# run_params: {'n': 13, 'm': 9} Train Acc: 0.99975 Test Acc: 0.94375
# test acc:  0.94375
# run_params: {'n': 167, 'm': 18} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 145, 'm': 15} Train Acc: 1.0 Test Acc: 0.94125
# test acc:  0.94125
# run_params: {'n': 54, 'm': 13} Train Acc: 1.0 Test Acc: 0.946
# test acc:  0.946
# run_params: {'n': 19, 'm': 2} Train Acc: 1.0 Test Acc: 0.946
# test acc:  0.946
# run_params: {'n': 118, 'm': 7} Train Acc: 1.0 Test Acc: 0.9595
# test acc:  0.9595
# run_params: {'n': 197, 'm': 12} Train Acc: 1.0 Test Acc: 0.952
# test acc:  0.952
# run_params: {'n': 136, 'm': 11} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 54, 'm': 8} Train Acc: 1.0 Test Acc: 0.954
# test acc:  0.954
# run_params: {'n': 45, 'm': 4} Train Acc: 1.0 Test Acc: 0.961
# test acc:  0.961
# run_params: {'n': 78, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# run_params: {'n': 122, 'm': 17} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 36, 'm': 16} Train Acc: 1.0 Test Acc: 0.9355
# test acc:  0.9355
# iterations 1
# run_params: {'n': 31, 'm': 4} Train Acc: 1.0 Test Acc: 0.956
# test acc:  0.956
# run_params: {'n': 45, 'm': 6} Train Acc: 1.0 Test Acc: 0.95825
# test acc:  0.95825
# run_params: {'n': 78, 'm': 5} Train Acc: 1.0 Test Acc: 0.96225
# test acc:  0.96225
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 83, 'm': 7} Train Acc: 1.0 Test Acc: 0.95825
# test acc:  0.95825
# run_params: {'n': 68, 'm': 4} Train Acc: 1.0 Test Acc: 0.96125
# test acc:  0.96125
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 123, 'm': 7} Train Acc: 1.0 Test Acc: 0.95975
# test acc:  0.95975
# run_params: {'n': 152, 'm': 5} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# iterations 2
# run_params: {'n': 85, 'm': 6} Train Acc: 1.0 Test Acc: 0.962
# test acc:  0.962
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 78, 'm': 13} Train Acc: 1.0 Test Acc: 0.94875
# test acc:  0.94875
# run_params: {'n': 184, 'm': 4} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# run_params: {'n': 160, 'm': 14} Train Acc: 1.0 Test Acc: 0.945
# test acc:  0.945
# run_params: {'n': 103, 'm': 5} Train Acc: 1.0 Test Acc: 0.96325
# test acc:  0.96325
# run_params: {'n': 85, 'm': 17} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 80, 'm': 5} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# run_params: {'n': 108, 'm': 5} Train Acc: 1.0 Test Acc: 0.96425
# test acc:  0.96425
# iterations 3
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 152, 'm': 4} Train Acc: 1.0 Test Acc: 0.963
# test acc:  0.963
# run_params: {'n': 85, 'm': 5} Train Acc: 1.0 Test Acc: 0.96275
# test acc:  0.96275
# run_params: {'n': 152, 'm': 4} Train Acc: 1.0 Test Acc: 0.963
# test acc:  0.963
# run_params: {'n': 85, 'm': 5} Train Acc: 1.0 Test Acc: 0.96275
# test acc:  0.96275
# run_params: {'n': 34, 'm': 5} Train Acc: 1.0 Test Acc: 0.958
# test acc:  0.958
# run_params: {'n': 95, 'm': 5} Train Acc: 1.0 Test Acc: 0.9625
# test acc:  0.9625
# run_params: {'n': 85, 'm': 11} Train Acc: 1.0 Test Acc: 0.95325
# test acc:  0.95325
# run_params: {'n': 152, 'm': 4} Train Acc: 1.0 Test Acc: 0.963
# test acc:  0.963
# iterations 4
# run_params: {'n': 89, 'm': 12} Train Acc: 1.0 Test Acc: 0.95075
# test acc:  0.95075
# run_params: {'n': 84, 'm': 14} Train Acc: 1.0 Test Acc: 0.947
# test acc:  0.947
# run_params: {'n': 85, 'm': 11} Train Acc: 1.0 Test Acc: 0.95325
# test acc:  0.95325
# run_params: {'n': 85, 'm': 13} Train Acc: 1.0 Test Acc: 0.9495
# test acc:  0.9495
# run_params: {'n': 70, 'm': 10} Train Acc: 1.0 Test Acc: 0.954
# test acc:  0.954
# run_params: {'n': 84, 'm': 7} Train Acc: 1.0 Test Acc: 0.958
# test acc:  0.958
# run_params: {'n': 54, 'm': 19} Train Acc: 0 Test Acc: 0
# test acc:  0
# run_params: {'n': 85, 'm': 5} Train Acc: 1.0 Test Acc: 0.96275
# test acc:  0.96275
# run_params: {'n': 152, 'm': 4} Train Acc: 1.0 Test Acc: 0.963
# test acc:  0.963
# run_params: {'n': 142, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# iterations 5
# run_params: {'n': 124, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 105, 'm': 5} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 67, 'm': 4} Train Acc: 1.0 Test Acc: 0.96075
# test acc:  0.96075
# run_params: {'n': 120, 'm': 4} Train Acc: 1.0 Test Acc: 0.9635
# test acc:  0.9635
# run_params: {'n': 47, 'm': 1} Train Acc: 1.0 Test Acc: 0.94975
# test acc:  0.94975
# run_params: {'n': 124, 'm': 4} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 152, 'm': 2} Train Acc: 1.0 Test Acc: 0.96175
# test acc:  0.96175
# run_params: {'n': 86, 'm': 5} Train Acc: 1.0 Test Acc: 0.963
# test acc:  0.963
# run_params: {'n': 152, 'm': 7} Train Acc: 1.0 Test Acc: 0.96025
# test acc:  0.96025
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# iterations 6
# run_params: {'n': 152, 'm': 5} Train Acc: 1.0 Test Acc: 0.964
# test acc:  0.964
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 168, 'm': 4} Train Acc: 1.0 Test Acc: 0.96325
# test acc:  0.96325
# run_params: {'n': 84, 'm': 13} Train Acc: 1.0 Test Acc: 0.94825
# test acc:  0.94825
# run_params: {'n': 78, 'm': 5} Train Acc: 1.0 Test Acc: 0.96225
# test acc:  0.96225
# run_params: {'n': 83, 'm': 10} Train Acc: 1.0 Test Acc: 0.95425
# test acc:  0.95425
# run_params: {'n': 85, 'm': 16} Train Acc: 1.0 Test Acc: 0.93825
# test acc:  0.93825
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 138, 'm': 5} Train Acc: 1.0 Test Acc: 0.9645
# test acc:  0.9645
# iterations 7
# run_params: {'n': 117, 'm': 4} Train Acc: 1.0 Test Acc: 0.963
# test acc:  0.963
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 24, 'm': 10} Train Acc: 0.9999375 Test Acc: 0.94825
# test acc:  0.94825
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 9} Train Acc: 1.0 Test Acc: 0.95525
# test acc:  0.95525
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 138, 'm': 5} Train Acc: 1.0 Test Acc: 0.9645
# test acc:  0.9645
# run_params: {'n': 138, 'm': 5} Train Acc: 1.0 Test Acc: 0.9645
# test acc:  0.9645
# iterations 8
# run_params: {'n': 108, 'm': 4} Train Acc: 1.0 Test Acc: 0.96375
# test acc:  0.96375
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 10} Train Acc: 1.0 Test Acc: 0.9545
# test acc:  0.9545
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 107, 'm': 10} Train Acc: 1.0 Test Acc: 0.9565
# test acc:  0.9565
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# iterations 9
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 16} Train Acc: 1.0 Test Acc: 0.939
# test acc:  0.939
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 6} Train Acc: 1.0 Test Acc: 0.962
# test acc:  0.962
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 35, 'm': 4} Train Acc: 1.0 Test Acc: 0.9565
# test acc:  0.9565
# run_params: {'n': 85, 'm': 10} Train Acc: 1.0 Test Acc: 0.95525
# test acc:  0.95525
# run_params: {'n': 85, 'm': 8} Train Acc: 1.0 Test Acc: 0.954
# test acc:  0.954
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# iterations 10
# run_params: {'n': 106, 'm': 4} Train Acc: 1.0 Test Acc: 0.96325
# test acc:  0.96325
# run_params: {'n': 54, 'm': 4} Train Acc: 1.0 Test Acc: 0.9605
# test acc:  0.9605
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 3} Train Acc: 1.0 Test Acc: 0.96125
# test acc:  0.96125
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
# run_params: {'n': 85, 'm': 16} Train Acc: 1.0 Test Acc: 0.93825
# test acc:  0.93825
# run_params: {'n': 84, 'm': 4} Train Acc: 1.0 Test Acc: 0.965
# test acc:  0.965
#  The best solution found:
#  [85.16813953  4.67008571]
#
#  Objective function:
#  -0.965
# Time to execute: 422.7507 seconds
# Best Position: [85, 4] Best Solution: -0.96500

# %%
model.best_function
# Out:
# -0.965
