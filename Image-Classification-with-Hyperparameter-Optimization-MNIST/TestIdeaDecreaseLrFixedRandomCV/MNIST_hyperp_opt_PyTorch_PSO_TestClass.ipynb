# %%
import torch

import torchvision
import os
from pathlib import Path
import time

# Import libraries
import os
import time
import random
import numpy as np
from numpy import argmax
import pandas as pd
import json
from collections import OrderedDict, namedtuple
from itertools import product
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import torchvision
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

# %%
if IN_COLAB:

    from google.colab import drive
    drive.mount('/drive', force_remount=True)
    datadir = '/drive/My Drive/Colab Notebooks/Datasets/'
    optim_dir = datadir + '/optim_dir/'
    results_folder = datadir+'/results/'
    Path(results_folder).mkdir(parents=True, exist_ok=True)
    Path(optim_dir).mkdir(parents=True, exist_ok=True)
else:
  results_folder = 'results'
  optim_dir = 'optim_dir'
  Path("results").mkdir(parents=True, exist_ok=True)
  Path(optim_dir).mkdir(parents=True, exist_ok=True)


# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO
# Out:
# Mounted at /drive

# %%
import sys
if IN_COLAB:
  print('yes')
  scripts_dir = '/drive/My Drive/Colab Notebooks/scripts/'
  sys.path.insert(1, scripts_dir)
# from opfunu.cec_basic.cec2014_nobias import *
# from mealpy.swarm_based.PSO import BasePSO

# insert at 1, 0 is the script path (or '' in REPL)
else:
    sys.path.insert(1, 'scripts')
from PSO import BasePSO
# Out:
# yes

# %%
# Enable GPU processing
if IN_COLAB:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
else:
    device = torch.device("cpu")
print(f'Device type: {device}')
# Out:
# Device type: cuda

# %%
n_epochs = 3
batch_size_train = 64
batch_size_test = 1000
learning_rate = 0.01
momentum = 0.5
log_interval = 10

random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %%
# Set random seed
seed = 777
torch.manual_seed(seed)
model = None

# %%
import random
def seeding(SEED):
    np.random.seed(SEED)
    random.seed(SEED)
    os.environ['PYTHONHASHSEED'] = str(SEED)
    os.environ['TF_CUDNN_DETERMINISTIC'] = str(SEED)
    # tf.random.set_seed(SEED)
    print('seeding done!!!')
seeding(seed)
# Out:
# seeding done!!!

# %%
train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST(datadir, train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST(datadir, train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=True)

data = {
    'train': 
    torchvision.datasets.MNIST(datadir, train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
    'val': 
    torchvision.datasets.MNIST(datadir, train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ]))
}

# %%
examples = enumerate(test_loader)
batch_idx, (example_data, example_targets) = next(examples)

# %%
example_data.shape
# Out:
# torch.Size([1000, 1, 28, 28])

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.tight_layout()
    plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
    plt.title("Ground Truth: {}".format(example_targets[i]))
    plt.xticks([])
    plt.yticks([])

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(1600, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = torch.flatten(x, 1)
        # exit()
        x = self.dropout2(x)
        
        x = self.fc1(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
network = Net()
optimizer = optim.SGD(network.parameters(), lr=learning_rate,
                      momentum=momentum)

# If we were using a GPU for training, we should have also sent 
# the network parameters to the GPU using e.g. network.cuda(). 
# It is important to transfer the network's parameters to the appropriate 
# device before passing them to the optimizer, otherwise the optimizer will 
# not be able to keep track of them in the right way.

# %%
print(network)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=1600, out_features=10, bias=True)
# )

# %%
# Define a class to build run execution sets based on a dictionary of hyperparameters
class RunBuilder():
    @staticmethod
    def get_runs(params):
        Run = namedtuple('Run', params.keys())
        runs = []
        for v in product(*params.values()):
            runs.append(Run(*v))
        return runs

# %%
# Create a class to manage the training / hyperparameter runs
class RunManager():
  def __init__(self):
    self.epoch_count = 0
    self.train_loss = 0
    self.train_num_correct = 0
    self.val_loss = 0
    self.val_num_correct = 0

    self.run_params = None
    self.run_count = 0
    self.run_data = []

    self.model = None
    self.train_loader = None
    self.val_loader = None
    self.tb = None
    
    #---
    self.results = None

  def begin_run(self, run, model, train_loader, val_loader):
    self.run_params = run
    self.run_count += 1
    self.model = model.to(device)
    self.train_loader = train_loader
    self.val_loader = val_loader
    self.tb = SummaryWriter(log_dir='/runs', max_queue=20, comment=f'-{run}')
    images, labels = next(iter(self.train_loader))
    images, labels = images.to(device), labels.to(device)
    self.tb.add_graph(self.model, images)
    

  def end_run(self):
    self.tb.close()
    self.epoch_count = 0

  def begin_epoch(self):
    self.epoch_count += 1
    self.train_loss = 0
    self.train_num_correct = 0
    self.val_loss = 0
    self.val_num_correct = 0

  def end_epoch(self):
    train_loss = self.train_loss / len(self.train_loader.dataset)
    train_accuracy = self.train_num_correct / len(self.train_loader.dataset)
    val_loss = self.val_loss / len(self.val_loader.dataset)
    val_accuracy = self.val_num_correct / len(self.val_loader.dataset)

    self.tb.add_scalar('Train Loss', train_loss, self.epoch_count)
    self.tb.add_scalar('Train Accuracy', train_accuracy, self.epoch_count)
    self.tb.add_scalar('Val Loss', val_loss, self.epoch_count)
    self.tb.add_scalar('Val Accuracy', val_accuracy, self.epoch_count)

    for name, param in self.model.named_parameters():
      self.tb.add_histogram(name, param, self.epoch_count)
      #self.tb.add_histogram(f'{name}.grad', param.grad, self.epoch_count)

    print(f'Epoch: {self.epoch_count}, Train Loss: {train_loss:.3f}, Train Acc: {train_accuracy:.4f}')
    print(f'Epoch: {self.epoch_count}, Valid Loss: {val_loss:.3f}, Valid Acc: {val_accuracy:.4f}')
    
    results = OrderedDict()
    results['run'] = self.run_count
    results['epoch'] = self.epoch_count
    results['train loss'] = train_loss
    results['train acc'] = train_accuracy
    results['valid loss'] = val_loss
    results['valid acc'] = val_accuracy
    
    # ---
    self.results = results

    for k, v in self.run_params.items():
      results[k] = v

    self.run_data.append(results)

  def track_loss(self, loss, mode):
    if mode == 'train':
      self.train_loss += loss.item() * self.train_loader.batch_size
    elif mode == 'val':
      self.val_loss += loss.item() * self.val_loader.batch_size

  def track_num_correct(self, preds, labels, mode):
    if mode == 'train':
      self.train_num_correct += preds.argmax(dim=1).eq(labels).sum().item()
    elif mode == 'val':
      self.val_num_correct += preds.argmax(dim=1).eq(labels).sum().item()

  def save_output(self, filename):
    if filename:
      filename = filename
      pd.DataFrame.from_dict(self.run_data, orient='columns').to_csv(f'{filename}.csv')
      
      # with open(f'{filename}.json', 'w', encoding='utf-8') as f:
      #   json.dump(self.run_data, f, ensure_ascii=False, indent=4)

      # print('Results saved to disk')

    return pd.DataFrame.from_dict(self.run_data, orient='columns')

# %%
# Define training loop execution
class ExecutionManager():
    def __init__(self, params=None):
      self.seeding(777)

    def seeding(self, SEED):
        # np.random.seed(SEED)
        # random.seed(SEED)
        # os.environ['PYTHONHASHSEED'] = str(SEED)
        os.environ['TF_CUDNN_DETERMINISTIC'] = str(SEED)
        torch.manual_seed(seed)
        # tf.random.set_seed(SEED)
        print('seeding done!!!')
    
    def reset_weights(self, model):
        for layer in model.children():
            if hasattr(layer, 'reset_parameters'):
                # print(f'Reset trainable parameters of layer = {layer}')
                layer.reset_parameters()

    def execution_loop(self, m, model, args, dataloaders=None): # args is given by the optimizer

        # self.seeding(777)
        print(args)
        model.apply(self.reset_weights)

        agent = {}
        agents = []
        power = args[0].astype(int)
        num = args[0] - power 
        tmp = num * 10.0**-power
        agent['lr'] = round(tmp, 6)
        agent['batch_size'] = int(args[1])
        agents.append(agent)
        #     m = RunManager()
        for run in agents: # this should be one. a particle in pso

            count = 0
            prev_valid_accs = []

            # instantiate the neural network model
            #     model = CNN_model(run.hidden_units, run.dropout, run.num_classes) 
            optimizer = Adam(model.parameters(), lr=run['lr'])

            # Define the data loaders
            if dataloaders is None:
                dataloaders = {
                    'train': DataLoader(data['train'], batch_size=run['batch_size'], shuffle=True, num_workers=1),
                    'val': DataLoader(data['val'], batch_size=run['batch_size'], shuffle=False, num_workers=1)
                }

            train_loader = dataloaders['train']
            val_loader = dataloaders['val']  

            print(f'Run Params: {run}')

            m.begin_run(run, model, train_loader, val_loader)
            for epoch in range(params['n_epochs'][0]):
                
                if epoch > 2:
                    
                    if prev_valid_acc < 0.7:
                        break
                if epoch > 15:
                    
                    if max(prev_valid_accs) < 0.97:
                        break
                if epoch > 19:
                    
                    if max(prev_valid_accs) < 0.98:
                        break
                if epoch > 8 and prev_valid_accs[-1] <= prev_valid_accs[-2]:
                    for i in range(2, len(prev_valid_accs)):
                        if prev_valid_accs[-1] <= prev_valid_accs[-i]:
                            count += 1
                            if count > 3:
                                optimizer.param_groups[0]['lr'] = run['lr'] * 0.1
                                count = 0
                                break
                m.begin_epoch()
                for batch in train_loader:
                    with torch.set_grad_enabled(True):
                        # get inputs/targets and move tensors to GPU
                        images, labels = batch[0].to(device), batch[1].to(device)
                        # clear previous gradients
                        optimizer.zero_grad()
                        # make prediction
                        yhat = model(images)
                        # calculate the loss
                        loss = F.nll_loss(yhat, labels)
                        # perform back prop
                        loss.backward()
                        # update model weights
                        optimizer.step()

                        m.track_loss(loss, 'train')
                        m.track_num_correct(yhat, labels, 'train')

                else:
                    with torch.no_grad():
                        for batch in val_loader:
                            images, labels = batch[0].to(device), batch[1].to(device)
                            output = model(images)
                            loss = F.nll_loss(output, labels)

                            m.track_loss(loss, 'val')
                            m.track_num_correct(output, labels, 'val')

                m.end_epoch()
                prev_valid_acc = m.results['valid acc']
                prev_valid_accs.append(prev_valid_acc)
        m.end_run()
        return model, max(prev_valid_accs)

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

# %%
# Define training run hyperparameters
params = {
    'hidden_units' : [256],
    'dropout' : [0.5],
    'num_classes' : [10],
    'lr' : [0, 1],
    'batch_size' : [20, 2000],
    'n_epochs' : [10]
}

# %%
m = RunManager()
timestr = time.strftime("%Y%m%d-%H%M%S")
filename = f'Run_Results-MNIST-PSO-test-idea-lr-FR--{timestr}'
# filename = 'Run_Results-MNIST-BBO-test-idea-lr---20210512-083324-cont' # this is for trying to continue from last optim save

# %%
def run_train_model(agent):
    network = Net()
    ex = ExecutionManager(params)
    model, valid_acc = ex.execution_loop(m, network, agent)
    m.save_output(f'{results_folder}/{filename}')
    print("valid acc: ", valid_acc)
    return valid_acc * -1

# %%
verbose = True
pop_size = 10   
max_iter = 10

obj_func = run_train_model

lb = [0, params['batch_size'][0]]
ub = [4, params['batch_size'][1]]

md2 = BasePSO(obj_func, lb, ub, verbose, max_iter, pop_size, random_seed=seed)  # Remember the keyword "problem_size"
best_pos1, best_fit1, list_loss1 = md2.train(f"{optim_dir}/pso_data-{timestr}.data")
# tmp = 'pso_data-20210504-035642.data'
# best_pos1, best_fit1, list_loss1 = md2.train(f"{optim_dir}/{tmp}", optim_data['epoch_count'], optim_data['v_list'], optim_data['pop'])
print(md2.solution[1])

# m.save_output(f'{results_folder}/{filename}')
# print('Results saved.')
# Out:
# seeding done!!!
# [6.10654940e-01 6.18666087e+02]
# Run Params: {'lr': 0.610655, 'batch_size': 618}
# Epoch: 1, Train Loss: 388.128, Train Acc: 0.1033
# Epoch: 1, Valid Loss: 2.430, Valid Acc: 0.1010
# Epoch: 2, Train Loss: 2.333, Train Acc: 0.1007
# Epoch: 2, Valid Loss: 2.431, Valid Acc: 0.1010
# Epoch: 3, Train Loss: 2.332, Train Acc: 0.1041
# Epoch: 3, Valid Loss: 2.430, Valid Acc: 0.1135
# valid acc:  0.1135
# seeding done!!!
# [2.48145659e-01 9.30523476e+02]
# Run Params: {'lr': 0.248146, 'batch_size': 930}
# Epoch: 1, Train Loss: 53.276, Train Acc: 0.1100
# Epoch: 1, Valid Loss: 2.354, Valid Acc: 0.1135
# Epoch: 2, Train Loss: 2.320, Train Acc: 0.1068
# Epoch: 2, Valid Loss: 2.355, Valid Acc: 0.1135
# Epoch: 3, Train Loss: 2.321, Train Acc: 0.1066
# Epoch: 3, Valid Loss: 2.358, Valid Acc: 0.0974
# valid acc:  0.1135
# seeding done!!!
# [   3.34101354 1855.45415454]
# Run Params: {'lr': 0.000341, 'batch_size': 1855}
# Epoch: 1, Train Loss: 1.547, Train Acc: 0.5516
# Epoch: 1, Valid Loss: 0.813, Valid Acc: 0.7900
# Epoch: 2, Train Loss: 0.533, Train Acc: 0.8414
# Epoch: 2, Valid Loss: 0.397, Valid Acc: 0.8968
# Epoch: 3, Train Loss: 0.321, Train Acc: 0.9072
# Epoch: 3, Valid Loss: 0.279, Valid Acc: 0.9297
# Epoch: 4, Train Loss: 0.244, Train Acc: 0.9302
# Epoch: 4, Valid Loss: 0.225, Valid Acc: 0.9429
# Epoch: 5, Train Loss: 0.198, Train Acc: 0.9435
# Epoch: 5, Valid Loss: 0.180, Valid Acc: 0.9541
# Epoch: 6, Train Loss: 0.169, Train Acc: 0.9518
# Epoch: 6, Valid Loss: 0.152, Valid Acc: 0.9606
# Epoch: 7, Train Loss: 0.151, Train Acc: 0.9577
# Epoch: 7, Valid Loss: 0.144, Valid Acc: 0.9609
# Epoch: 8, Train Loss: 0.135, Train Acc: 0.9618
# Epoch: 8, Valid Loss: 0.126, Valid Acc: 0.9668
# Epoch: 9, Train Loss: 0.123, Train Acc: 0.9640
# Epoch: 9, Valid Loss: 0.123, Valid Acc: 0.9670
# Epoch: 10, Train Loss: 0.115, Train Acc: 0.9667
# Epoch: 10, Valid Loss: 0.110, Valid Acc: 0.9697
# valid acc:  0.9697
# seeding done!!!
# [   2.90795594 1541.6225194 ]
# Run Params: {'lr': 0.00908, 'batch_size': 1541}
# Epoch: 1, Train Loss: 0.923, Train Acc: 0.7220
# Epoch: 1, Valid Loss: 0.361, Valid Acc: 0.8956
# Epoch: 2, Train Loss: 0.280, Train Acc: 0.9116
# Epoch: 2, Valid Loss: 0.231, Valid Acc: 0.9328
# Epoch: 3, Train Loss: 0.206, Train Acc: 0.9363
# Epoch: 3, Valid Loss: 0.191, Valid Acc: 0.9447
# Epoch: 4, Train Loss: 0.177, Train Acc: 0.9453
# Epoch: 4, Valid Loss: 0.172, Valid Acc: 0.9499
# Epoch: 5, Train Loss: 0.161, Train Acc: 0.9483
# Epoch: 5, Valid Loss: 0.154, Valid Acc: 0.9561
# Epoch: 6, Train Loss: 0.156, Train Acc: 0.9513
# Epoch: 6, Valid Loss: 0.145, Valid Acc: 0.9579
# Epoch: 7, Train Loss: 0.146, Train Acc: 0.9547
# Epoch: 7, Valid Loss: 0.141, Valid Acc: 0.9573
# Epoch: 8, Train Loss: 0.137, Train Acc: 0.9568
# Epoch: 8, Valid Loss: 0.135, Valid Acc: 0.9605
# Epoch: 9, Train Loss: 0.132, Train Acc: 0.9587
# Epoch: 9, Valid Loss: 0.130, Valid Acc: 0.9634
# Epoch: 10, Train Loss: 0.127, Train Acc: 0.9595
# Epoch: 10, Valid Loss: 0.127, Valid Acc: 0.9624
# valid acc:  0.9634
# seeding done!!!
# [1.07682027e+00 1.29517800e+03]
# Run Params: {'lr': 0.007682, 'batch_size': 1295}
# Epoch: 1, Train Loss: 0.806, Train Acc: 0.7581
# Epoch: 1, Valid Loss: 0.276, Valid Acc: 0.9157
# Epoch: 2, Train Loss: 0.238, Train Acc: 0.9270
# Epoch: 2, Valid Loss: 0.192, Valid Acc: 0.9405
# Epoch: 3, Train Loss: 0.185, Train Acc: 0.9424
# Epoch: 3, Valid Loss: 0.175, Valid Acc: 0.9474
# Epoch: 4, Train Loss: 0.162, Train Acc: 0.9504
# Epoch: 4, Valid Loss: 0.142, Valid Acc: 0.9579
# Epoch: 5, Train Loss: 0.144, Train Acc: 0.9550
# Epoch: 5, Valid Loss: 0.135, Valid Acc: 0.9614
# Epoch: 6, Train Loss: 0.136, Train Acc: 0.9587
# Epoch: 6, Valid Loss: 0.126, Valid Acc: 0.9610
# Epoch: 7, Train Loss: 0.130, Train Acc: 0.9598
# Epoch: 7, Valid Loss: 0.124, Valid Acc: 0.9622
# Epoch: 8, Train Loss: 0.123, Train Acc: 0.9621
# Epoch: 8, Valid Loss: 0.118, Valid Acc: 0.9639
# Epoch: 9, Train Loss: 0.118, Train Acc: 0.9645
# Epoch: 9, Valid Loss: 0.108, Valid Acc: 0.9660
# Epoch: 10, Train Loss: 0.112, Train Acc: 0.9666
# Epoch: 10, Valid Loss: 0.106, Valid Acc: 0.9681
# valid acc:  0.9681
# seeding done!!!
# [  0.37349303 177.77805351]
# Run Params: {'lr': 0.373493, 'batch_size': 177}
# Epoch: 1, Train Loss: 28.113, Train Acc: 0.1020
# Epoch: 1, Valid Loss: 2.336, Valid Acc: 0.1028
# Epoch: 2, Train Loss: 2.316, Train Acc: 0.1050
# Epoch: 2, Valid Loss: 2.336, Valid Acc: 0.1028
# Epoch: 3, Train Loss: 2.317, Train Acc: 0.1019
# Epoch: 3, Valid Loss: 2.330, Valid Acc: 0.1135
# valid acc:  0.1135
# seeding done!!!
# [  2.35845501 699.81426568]
# Run Params: {'lr': 0.003585, 'batch_size': 699}
# Epoch: 1, Train Loss: 0.369, Train Acc: 0.8875
# Epoch: 1, Valid Loss: 0.107, Valid Acc: 0.9684
# Epoch: 2, Train Loss: 0.095, Train Acc: 0.9708
# Epoch: 2, Valid Loss: 0.074, Valid Acc: 0.9805
# Epoch: 3, Train Loss: 0.074, Train Acc: 0.9770
# Epoch: 3, Valid Loss: 0.068, Valid Acc: 0.9797
# Epoch: 4, Train Loss: 0.064, Train Acc: 0.9798
# Epoch: 4, Valid Loss: 0.058, Valid Acc: 0.9823
# Epoch: 5, Train Loss: 0.058, Train Acc: 0.9821
# Epoch: 5, Valid Loss: 0.059, Valid Acc: 0.9820
# Epoch: 6, Train Loss: 0.051, Train Acc: 0.9834
# Epoch: 6, Valid Loss: 0.058, Valid Acc: 0.9827
# Epoch: 7, Train Loss: 0.049, Train Acc: 0.9844
# Epoch: 7, Valid Loss: 0.048, Valid Acc: 0.9862
# Epoch: 8, Train Loss: 0.043, Train Acc: 0.9860
# Epoch: 8, Valid Loss: 0.050, Valid Acc: 0.9862
# Epoch: 9, Train Loss: 0.041, Train Acc: 0.9866
# Epoch: 9, Valid Loss: 0.056, Valid Acc: 0.9840
# Epoch: 10, Train Loss: 0.043, Train Acc: 0.9869
# Epoch: 10, Valid Loss: 0.052, Valid Acc: 0.9841
# valid acc:  0.9862
# seeding done!!!
# [   3.95550459 1260.41694833]
# Run Params: {'lr': 0.000956, 'batch_size': 1260}
# Epoch: 1, Train Loss: 0.740, Train Acc: 0.7764
# Epoch: 1, Valid Loss: 0.227, Valid Acc: 0.9305
# Epoch: 2, Train Loss: 0.187, Train Acc: 0.9452
# Epoch: 2, Valid Loss: 0.137, Valid Acc: 0.9596
# Epoch: 3, Train Loss: 0.127, Train Acc: 0.9626
# Epoch: 3, Valid Loss: 0.103, Valid Acc: 0.9688
# Epoch: 4, Train Loss: 0.102, Train Acc: 0.9695
# Epoch: 4, Valid Loss: 0.086, Valid Acc: 0.9738
# Epoch: 5, Train Loss: 0.088, Train Acc: 0.9731
# Epoch: 5, Valid Loss: 0.073, Valid Acc: 0.9773
# Epoch: 6, Train Loss: 0.081, Train Acc: 0.9757
# Epoch: 6, Valid Loss: 0.067, Valid Acc: 0.9789
# Epoch: 7, Train Loss: 0.070, Train Acc: 0.9794
# Epoch: 7, Valid Loss: 0.060, Valid Acc: 0.9807
# Epoch: 8, Train Loss: 0.066, Train Acc: 0.9801
# Epoch: 8, Valid Loss: 0.061, Valid Acc: 0.9806
# Epoch: 9, Train Loss: 0.061, Train Acc: 0.9809
# Epoch: 9, Valid Loss: 0.055, Valid Acc: 0.9814
# Epoch: 10, Train Loss: 0.058, Train Acc: 0.9824
# Epoch: 10, Valid Loss: 0.052, Valid Acc: 0.9838
# valid acc:  0.9838
# seeding done!!!
# [   2.72711712 1113.4684912 ]
# Run Params: {'lr': 0.007271, 'batch_size': 1113}
# Epoch: 1, Train Loss: 0.789, Train Acc: 0.7553
# Epoch: 1, Valid Loss: 0.251, Valid Acc: 0.9208
# Epoch: 2, Train Loss: 0.224, Train Acc: 0.9311
# Epoch: 2, Valid Loss: 0.179, Valid Acc: 0.9430
# Epoch: 3, Train Loss: 0.172, Train Acc: 0.9464
# Epoch: 3, Valid Loss: 0.144, Valid Acc: 0.9562
# Epoch: 4, Train Loss: 0.147, Train Acc: 0.9535
# Epoch: 4, Valid Loss: 0.138, Valid Acc: 0.9585
# Epoch: 5, Train Loss: 0.139, Train Acc: 0.9574
# Epoch: 5, Valid Loss: 0.123, Valid Acc: 0.9613
# Epoch: 6, Train Loss: 0.129, Train Acc: 0.9598
# Epoch: 6, Valid Loss: 0.117, Valid Acc: 0.9631
# Epoch: 7, Train Loss: 0.123, Train Acc: 0.9618
# Epoch: 7, Valid Loss: 0.116, Valid Acc: 0.9631
# Epoch: 8, Train Loss: 0.119, Train Acc: 0.9624
# Epoch: 8, Valid Loss: 0.111, Valid Acc: 0.9644
# Epoch: 9, Train Loss: 0.115, Train Acc: 0.9642
# Epoch: 9, Valid Loss: 0.100, Valid Acc: 0.9686
# Epoch: 10, Train Loss: 0.110, Train Acc: 0.9661
# Epoch: 10, Valid Loss: 0.102, Valid Acc: 0.9696
# valid acc:  0.9696
# seeding done!!!
# [  1.07544023 759.05358514]
# Run Params: {'lr': 0.007544, 'batch_size': 759}
# Epoch: 1, Train Loss: 0.588, Train Acc: 0.8216
# Epoch: 1, Valid Loss: 0.236, Valid Acc: 0.9364
# Epoch: 2, Train Loss: 0.196, Train Acc: 0.9405
# Epoch: 2, Valid Loss: 0.168, Valid Acc: 0.9510
# Epoch: 3, Train Loss: 0.153, Train Acc: 0.9522
# Epoch: 3, Valid Loss: 0.178, Valid Acc: 0.9473
# Epoch: 4, Train Loss: 0.138, Train Acc: 0.9567
# Epoch: 4, Valid Loss: 0.124, Valid Acc: 0.9639
# Epoch: 5, Train Loss: 0.123, Train Acc: 0.9625
# Epoch: 5, Valid Loss: 0.122, Valid Acc: 0.9651

# %%
best_pos1

# %%
def reset_weights(m):
  for layer in m.children():
   if hasattr(layer, 'reset_parameters'):
    print(f'Reset trainable parameters of layer = {layer}')
    layer.reset_parameters()

# %%
from torch.utils.data import DataLoader, ConcatDataset
from sklearn.model_selection import KFold

k_folds = 7
num_epochs = 1
loss_function = nn.CrossEntropyLoss()

# For fold results
results = {}

# Set fixed random number seed
torch.manual_seed(42)

# Prepare MNIST dataset by concatenating Train/Test part; we split later.
dataset_train_part = data['train']
dataset_test_part = data['val']
dataset = ConcatDataset([dataset_train_part, dataset_test_part])

# Define the K-fold Cross Validator
kfold = KFold(n_splits=k_folds, shuffle=True)
  
# Start print
print('--------------------------------')

# %%
# K-fold Cross Validation model evaluation
# for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset)):

#   print("train_ids: ", len(train_ids), "test_ids: ", len(test_ids))
  
#   # Print
#   print(f'FOLD {fold}')
#   print('--------------------------------')
  
#   # Sample elements randomly from a given list of ids, no replacement.
#   train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
#   test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)
  
#   # Define data loaders for training and testing data in this fold
#   trainloader = torch.utils.data.DataLoader(
#                     dataset, 
#                     batch_size=int(best_pos1[1]), sampler=train_subsampler)
#   testloader = torch.utils.data.DataLoader(
#                     dataset,
#                     batch_size=int(best_pos1[1]), sampler=test_subsampler)
  
#   loaders = {'train': trainloader, 'val': testloader}
  
#   # Init the neural network
#   network = Net()
#   # network.apply(reset_weights)
  
#   ex = ExecutionManager(params)

#   model, valid_acc = ex.execution_loop(m, network, best_pos1, loaders)
#   # m.save_output(f'{results_folder}/{filename}')
#   print("valid acc: ", valid_acc)

# %%
len(dataset)

# %%
params = {
    'hidden_units' : [256],
    'dropout' : [0.5],
    'num_classes' : [10],
    'lr' : [0, 1],
    'batch_size' : [20, 2000],
    'n_epochs' : [70]
}

network = Net()
# network.apply(reset_weights)

ex = ExecutionManager(params)

model, valid_acc = ex.execution_loop(m, network, np.array([2.1, 512]))
# m.save_output(f'{results_folder}/{filename}')
print("valid acc: ", valid_acc)

# %%
# Function to evaluate the model on the test set
def evaluate_model(test_dl, model):
    predictions, actuals = list(), list()
    for i, (inputs, targets) in enumerate(test_dl):
        # evaluate the model on the test set
        yhat = model(inputs)
        # retrieve numpy array
        yhat = yhat.detach().numpy()
        actual = targets.numpy()
        actual = actual.reshape((len(actual), 1))
        # round to class values
        yhat = yhat.round()
        # store
        predictions.append(yhat)
        actuals.append(actual)
    predictions, actuals = vstack(predictions), vstack(actuals)
    # calculate accuracy
    acc = accuracy_score(actuals, predictions)
    return acc

# %%
dfdfd

# %%
# Determine model accuracy on the test set
test_dl = DataLoader(data['test'], batch_size=params['batch_size'], shuffle=False, num_workers=1)
test_acc = evaluate_model(test_dl, model)

# %%
kjkjk

function ClickConnect(){
console.log("Working"); 
 var selector = "#cell-11a2b616"
document.querySelector(selector).click();
  document.querySelector(selector).value = 123;
}
setInterval(ClickConnect,60000)

# %%
dfdf

function ClickConnect(){
console.log("Working"); 
document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
}
var clicker = setInterval(ClickConnect,60000);

clearInterval(clicker);
